# %% [markdown]
# This notebook enables the user to reproduce the analysis steps we have performed for our study *They crossed the valley of Catamarca: A study of narrative space in novel openings* based on the annotation data saved as [Catma](https://www.catma.de) project in `/CATMA_4AA4ADC0-4C28-54F9-B6A1-5DCEFF34B90B_DH2025_CANSpiN` and as `.tsv` data in `/canspin-deu-19`, `/canspin-deu-20`, `/canspin-lat-19`, and `/canspin-spa-19`.
#
# If you wish to see the analysis results only, it is not necessary to execute this notebook. In this case, see our paper and the content of the `/results` folder.
#
# To use the notebook, install the [gitma-canspin package](https://github.com/CANSpiNproject/gitma-canspin/tree/v1.6.2) first, following the instructions of its README.

# %%
# imports
from gitma_canspin.canspin import AnnotationAnalyzer

import pandas as pd
import plotly
import json
import os
import itertools

from typing import Tuple

# %%
# load the analyzer with the catma project from the CATMA_4AA4ADC0-4C28-54F9-B6A1-5DCEFF34B90B_DH2025_CANSpiN folder
analyzer = AnnotationAnalyzer(init_settings={'project_name': 'CATMA_4AA4ADC0-4C28-54F9-B6A1-5DCEFF34B90B_DH2025_CANSpiN'})
# Out:
# gitma_canspin.project - INFO - Loading tagsets ...
# gitma_canspin.project - INFO - 	Found 3 tagset(s).
# gitma_canspin.project - INFO - Loading documents ...
# gitma_canspin.project - INFO - 	Found 6 document(s).
# gitma_canspin.project - INFO - Loading annotation collections ...
# gitma_canspin.project - INFO - 	Found 6 annotation collection(s).
# gitma_canspin.project - INFO - 	Annotation collection "Collection CS1 v1.1.0 - Gold Standard" for document "El pozo del Yocci"
# gitma_canspin.project - INFO - 		Annotations: 201
# gitma_canspin.project - INFO - 	Annotation collection "CS1 v1.1.0 - Nils (Gold: 1)" for document "El Señor de Bembibre"
# gitma_canspin.project - INFO - 		Annotations: 285
# gitma_canspin.project - INFO - 	Annotation collection "CS1 v1.1.0 - Ulrike (Gold standard: 1)" for document "CANSpiN-spa-19-008"
# gitma_canspin.project - INFO - 		Annotations: 1332
# gitma_canspin.project - INFO - 	Annotation collection "Nils -- CS1 1.1.0 (Gold: 1-1-1)" for document "DEU-19_001"
# gitma_canspin.project - INFO - 		Annotations: 898
# gitma_canspin.project - INFO - 	Annotation collection "Nils -- CS1 V.1.1.0 (Gold:1-1-1)" for document "DEU-19_030"
# gitma_canspin.project - INFO - 		Annotations: 1056
# gitma_canspin.project - INFO - 	Annotation collection "Collection CS1 v1.1.0 - Gold Standard" for document "El falso Inca"
# gitma_canspin.project - INFO - 		Annotations: 128
# gitma_canspin.canspin - INFO - The line endings of all texts of the loaded project have been unified to unix standard.

# %%
# display loaded tsv annotations from corpus folders
analyzer.print_tsv_annotations_overview()
# Out:
# gitma_canspin.canspin - INFO - tsv files found in canspin project!
# overview:
# - schema "cs1"
# 	CANSpiN-deu-19_001_1-1-1.tsv
# 	CANSpiN-deu-19_030_1-1-1.tsv
# 	CANSpiN-deu-20_002_1_shuffled.tsv
# 	CANSpiN-deu-20_021_1_shuffled.tsv
# 	CANSpiN-lat-19_004_1.tsv
# 	CANSpiN-lat-19_041_1.tsv
# 	CANSpiN-spa-19_001_1.tsv
# 	CANSpiN-spa-19_008_1.tsv

# %%
# display loaded annotation collections from catma project
analyzer.print_projects_annotation_collection_list()
# Out:
# Annotation collection list:
# index	collection_name	text_title
# 0	Collection CS1 v1.1.0 - Gold Standard	El pozo del Yocci
# 1	CS1 v1.1.0 - Nils (Gold: 1)	El Señor de Bembibre
# 2	CS1 v1.1.0 - Ulrike (Gold standard: 1)	CANSpiN-spa-19-008
# 3	Nils -- CS1 1.1.0 (Gold: 1-1-1)	DEU-19_001
# 4	Nils -- CS1 V.1.1.0 (Gold:1-1-1)	DEU-19_030
# 5	Collection CS1 v1.1.0 - Gold Standard	El falso Inca

# %% [markdown]
# ## steps
# Perform all steps in the specified order to obtain a correct result. You must not skip any steps in between.

# %% [markdown]
# ### 1 - get CS1 annotation statistics as JSON file

# %%
# get the annotation statistics from the tsv files (for the entire chapters and for the first 1000 tokens respectively)
# and translate the class names into English

token_selection: Tuple[int, int] = (0, 1000)

results: dict = {
    'whole_chapters': analyzer.get_corpus_annotation_statistics(),
    'first_1000_token': analyzer.get_corpus_annotation_statistics({
        'calculations': {
            'amount_of_annotations': True,
            'amount_of_annotations_by_class': True,
            'amount_of_token': True,
            'amount_of_annotated_token': True,
            'amount_of_annotated_token_by_class': True,
            'ratios': True,
            'word_lists_by_class': True
        },
        'custom_grouping': None,
        'text_borders': token_selection
    })
}

key_translation = {
    'Ort-Container': 'Place-Container',
    'Ort-Container-BK': 'Place-Container-MC',
    'Ort-Objekt': 'Place-Object',
    'Ort-Objekt-BK': 'Place-Object-MC',
    'Ort-Abstrakt': 'Place-Abstract',
    'Ort-Abstrakt-BK': 'Place-Abstract-MC',
    'Ort-ALT': 'Place-ALT',
    'Bewegung-Subjekt': 'Movement-Subject',
    'Bewegung-Objekt': 'Movement-Object',
    'Bewegung-Licht': 'Movement-Light',
    'Bewegung-Schall': 'Movement-Sound',
    'Bewegung-Geruch': 'Movement-Smell',
    'Bewegung-ALT': 'Movement-ALT',
    'Dimensionierung-Groesse': 'Dimensioning-Size',
    'Dimensionierung-Abstand': 'Dimensioning-Distance',
    'Dimensionierung-Menge': 'Dimensioning-Amount',
    'Dimensionierung-ALT': 'Dimensioning-ALT',
    'Positionierung': 'Positioning',
    'Positionierung-ALT': 'Positioning-ALT',
    'Richtung': 'Direction',
    'Richtung-ALT': 'Direction-ALT',
    'Lugar-Contenedor': 'Place-Container',
    'Lugar-Contenedor-CM': 'Place-Container-MC',
    'Lugar-Objeto': 'Place-Object',
    'Lugar-Objeto-CM': 'Place-Object-MC',
    'Lugar-Abstracto': 'Place-Abstract',
    'Lugar-Abstracto-CM': 'Place-Abstract-MC',
    'Lugar-ALT': 'Place-ALT',
    'Movimiento-Sujeto': 'Movement-Subject',
    'Movimiento-Objeto': 'Movement-Object',
    'Movimiento-Luz': 'Movement-Light',
    'Movimiento-Sonido': 'Movement-Sound',
    'Movimiento-Olfato': 'Movement-Smell',
    'Movimiento-ALT': 'Movement-ALT',
    'Dimensionamiento-Tamaño': 'Dimensioning-Size',
    'Dimensionamiento-Distancia': 'Dimensioning-Distance',
    'Dimensionamiento-Cantitad': 'Dimensioning-Amount',
    'Dimensionamiento-ALT': 'Dimensioning-ALT',
    'Posicionamiento': 'Positioning',
    'Posicionamiento-ALT': 'Positioning-ALT',
    'Dirección': 'Direction',
    'Dirección-ALT': 'Direction-ALT'
}

def merge_word_list_by_class_dicts(first: dict, second: dict) -> dict:
    result = first
    for token, token_amount in second.items():
        if token not in result:
            result[token] = token_amount
            continue
        result[token] = result[token] + token_amount
    result = dict(sorted(result.items(), key=lambda x: int(x[1]), reverse=True))
    return result

def translate_dict(input: dict, translation: dict) -> dict:
    translated = {}
    if len([key for key in input if key in key_translation]) == len(key_translation):
        # for translating schema totals per class with mixed german and spanish classes...
        if isinstance(input[list(key_translation.keys())[0]], int):
            # ...in case of class instances amounts
            for key, value in input.items():
                translated_key: str = key_translation[key]
                translated[translated_key] = value if not translated.get(translated_key) else translated[translated_key] + value
            translated = dict(sorted(translated.items(), key=lambda x: int(x[1]), reverse=True))
        elif isinstance(input[list(key_translation.keys())[0]], dict):
            # ...in case of word lists
            for key, value in input.items():
                translated_key: str = key_translation[key]
                translated[translated_key] = value if not translated.get(translated_key) else merge_word_list_by_class_dicts(translated[translated_key], value)
    else:
        # for translating everything else
        translated = dict([(translation.get(k, k), v) for k, v in input.items()])
    for key, value in translated.items():
        if isinstance(value, dict):
            translated[key] = translate_dict(value, translation)
    return translated

for result_type in results:
    results[result_type] = translate_dict(input=results[result_type], translation=key_translation)

# %%
# print annotation statistics

for result_type in results:
    print(
        json.dumps(
            results[result_type],
            indent=2, 
            sort_keys=False, 
            ensure_ascii=False
        )
    )
# Out:
# {
#   "amount_of_annotations": {
#     "cs1": {
#       "canspin-lat-19": {
#         "CANSpiN-lat-19_004_1.tsv": 128,
#         "CANSpiN-lat-19_041_1.tsv": 199,
#         "TOTAL": 327
#       },
#       "canspin-deu-19": {
#         "CANSpiN-deu-19_001_1-1-1.tsv": 898,
#         "CANSpiN-deu-19_030_1-1-1.tsv": 1056,
#         "TOTAL": 1954
#       },
#       "canspin-deu-20": {
#         "CANSpiN-deu-20_002_1_shuffled.tsv": 412,
#         "CANSpiN-deu-20_021_1_shuffled.tsv": 154,
#         "TOTAL": 566
#       },
#       "canspin-spa-19": {
#         "CANSpiN-spa-19_001_1.tsv": 269,
#         "CANSpiN-spa-19_008_1.tsv": 728,
#         "TOTAL": 997
#       },
#       "TOTAL": 3844
#     }
#   },
#   "amount_of_annotations_by_class": {
#     "cs1": {
#       "canspin-lat-19": {
#         "CANSpiN-lat-19_004_1.tsv": {
#           "Movement-ALT": 20,
#           "Movement-Subject": 19,
#           "Place-Container": 16,
#           "Positioning": 16,
#           "Dimensioning-Amount": 10,
#           "Movement-Object": 9,
#           "Movement-Sound": 8,
#           "Place-Container-MC": 7,
#           "Dimensioning-Size": 6,
#           "Direction": 5,
#           "Movement-Light": 4,
#           "Dimensioning-Distance": 3,
#           "Dimensioning-ALT": 2,
#           "Place-Object": 1,
#           "Direction-ALT": 1,
#           "Place-Object-MC": 1,
#           "Place-Abstract": 0,
#           "Place-Abstract-MC": 0,
#           "Place-ALT": 0,
#           "Movement-Smell": 0,
#           "Positioning-ALT": 0
#         },
#         "CANSpiN-lat-19_041_1.tsv": {
#           "Place-Container": 60,
#           "Positioning": 33,
#           "Movement-Subject": 29,
#           "Movement-ALT": 17,
#           "Direction": 12,
#           "Dimensioning-Amount": 10,
#           "Dimensioning-Size": 8,
#           "Place-Object": 6,
#           "Movement-Light": 4,
#           "Place-Container-MC": 4,
#           "Movement-Sound": 4,
#           "Place-ALT": 3,
#           "Positioning-ALT": 2,
#           "Dimensioning-Distance": 2,
#           "Movement-Object": 2,
#           "Dimensioning-ALT": 1,
#           "Direction-ALT": 1,
#           "Place-Abstract": 1,
#           "Place-Object-MC": 0,
#           "Place-Abstract-MC": 0,
#           "Movement-Smell": 0
#         },
#         "TOTAL": {
#           "Movement-ALT": 37,
#           "Movement-Subject": 48,
#           "Place-Container": 76,
#           "Positioning": 49,
#           "Dimensioning-Amount": 20,
#           "Movement-Object": 11,
#           "Movement-Sound": 12,
#           "Place-Container-MC": 11,
#           "Dimensioning-Size": 14,
#           "Direction": 17,
#           "Movement-Light": 8,
#           "Dimensioning-Distance": 5,
#           "Dimensioning-ALT": 3,
#           "Place-Object": 7,
#           "Direction-ALT": 2,
#           "Place-Object-MC": 1,
#           "Place-Abstract": 1,
#           "Place-Abstract-MC": 0,
#           "Place-ALT": 3,
#           "Movement-Smell": 0,
#           "Positioning-ALT": 2
#         }
#       },
#       "canspin-deu-19": {
#         "CANSpiN-deu-19_001_1-1-1.tsv": {
#           "Place-Container": 131,
#           "Movement-Subject": 126,
#           "Positioning": 120,
#           "Movement-ALT": 105,
#           "Direction": 95,
#           "Movement-Sound": 92,
#           "Dimensioning-Amount": 52,
#           "Movement-Light": 35,
#           "Dimensioning-Size": 33,
#           "Place-Container-MC": 32,
#           "Dimensioning-Distance": 15,
#           "Place-Object": 10,
#           "Place-Abstract": 10,
#           "Dimensioning-ALT": 10,
#           "Movement-Object": 9,
#           "Direction-ALT": 7,
#           "Place-Object-MC": 6,
#           "Place-ALT": 5,
#           "Positioning-ALT": 4,
#           "Place-Abstract-MC": 1,
#           "Movement-Smell": 0
#         },
#         "CANSpiN-deu-19_030_1-1-1.tsv": {
#           "Movement-ALT": 187,
#           "Positioning": 133,
#           "Movement-Subject": 122,
#           "Movement-Sound": 102,
#           "Place-Container": 91,
#           "Direction": 86,
#           "Movement-Light": 51,
#           "Dimensioning-Amount": 44,
#           "Direction-ALT": 37,
#           "Place-ALT": 37,
#           "Dimensioning-Size": 36,
#           "Dimensioning-ALT": 28,
#           "Place-Object": 25,
#           "Movement-Object": 23,
#           "Place-Container-MC": 20,
#           "Positioning-ALT": 12,
#           "Place-Object-MC": 8,
#           "Dimensioning-Distance": 7,
#           "Place-Abstract": 5,
#           "Place-Abstract-MC": 2,
#           "Movement-Smell": 0
#         },
#         "TOTAL": {
#           "Place-Container": 222,
#           "Movement-Subject": 248,
#           "Positioning": 253,
#           "Movement-ALT": 292,
#           "Direction": 181,
#           "Movement-Sound": 194,
#           "Dimensioning-Amount": 96,
#           "Movement-Light": 86,
#           "Dimensioning-Size": 69,
#           "Place-Container-MC": 52,
#           "Dimensioning-Distance": 22,
#           "Place-Object": 35,
#           "Place-Abstract": 15,
#           "Dimensioning-ALT": 38,
#           "Movement-Object": 32,
#           "Direction-ALT": 44,
#           "Place-Object-MC": 14,
#           "Place-ALT": 42,
#           "Positioning-ALT": 16,
#           "Place-Abstract-MC": 3,
#           "Movement-Smell": 0
#         }
#       },
#       "canspin-deu-20": {
#         "CANSpiN-deu-20_002_1_shuffled.tsv": {
#           "Movement-Subject": 75,
#           "Movement-ALT": 66,
#           "Direction": 54,
#           "Place-Container": 50,
#           "Movement-Sound": 44,
#           "Positioning": 42,
#           "Place-Container-MC": 17,
#           "Place-ALT": 15,
#           "Direction-ALT": 13,
#           "Positioning-ALT": 7,
#           "Dimensioning-ALT": 6,
#           "Movement-Light": 5,
#           "Dimensioning-Amount": 4,
#           "Movement-Smell": 3,
#           "Movement-Object": 3,
#           "Place-Object": 2,
#           "Place-Object-MC": 2,
#           "Dimensioning-Distance": 1,
#           "Dimensioning-Size": 1,
#           "Place-Abstract": 1,
#           "Place-Abstract-MC": 1
#         },
#         "CANSpiN-deu-20_021_1_shuffled.tsv": {
#           "Place-Container": 37,
#           "Movement-Subject": 28,
#           "Positioning": 22,
#           "Movement-ALT": 19,
#           "Direction": 16,
#           "Dimensioning-Size": 5,
#           "Place-Container-MC": 4,
#           "Direction-ALT": 4,
#           "Movement-Light": 4,
#           "Movement-Object": 3,
#           "Dimensioning-Amount": 2,
#           "Place-ALT": 2,
#           "Place-Object": 2,
#           "Place-Object-MC": 2,
#           "Dimensioning-ALT": 2,
#           "Movement-Sound": 1,
#           "Dimensioning-Distance": 1,
#           "Place-Abstract": 0,
#           "Place-Abstract-MC": 0,
#           "Movement-Smell": 0,
#           "Positioning-ALT": 0
#         },
#         "TOTAL": {
#           "Movement-Subject": 103,
#           "Movement-ALT": 85,
#           "Direction": 70,
#           "Place-Container": 87,
#           "Movement-Sound": 45,
#           "Positioning": 64,
#           "Place-Container-MC": 21,
#           "Place-ALT": 17,
#           "Direction-ALT": 17,
#           "Positioning-ALT": 7,
#           "Dimensioning-ALT": 8,
#           "Movement-Light": 9,
#           "Dimensioning-Amount": 6,
#           "Movement-Smell": 3,
#           "Movement-Object": 6,
#           "Place-Object": 4,
#           "Place-Object-MC": 4,
#           "Dimensioning-Distance": 2,
#           "Dimensioning-Size": 6,
#           "Place-Abstract": 1,
#           "Place-Abstract-MC": 1
#         }
#       },
#       "canspin-spa-19": {
#         "CANSpiN-spa-19_001_1.tsv": {
#           "Movement-ALT": 72,
#           "Movement-Subject": 37,
#           "Direction": 35,
#           "Place-Container": 24,
#           "Movement-Sound": 20,
#           "Positioning": 15,
#           "Direction-ALT": 12,
#           "Place-Container-MC": 11,
#           "Dimensioning-Amount": 7,
#           "Place-ALT": 6,
#           "Dimensioning-Size": 6,
#           "Movement-Object": 6,
#           "Movement-Light": 5,
#           "Place-Object": 5,
#           "Dimensioning-ALT": 3,
#           "Positioning-ALT": 3,
#           "Dimensioning-Distance": 2,
#           "Place-Object-MC": 0,
#           "Place-Abstract": 0,
#           "Place-Abstract-MC": 0,
#           "Movement-Smell": 0
#         },
#         "CANSpiN-spa-19_008_1.tsv": {
#           "Positioning": 126,
#           "Place-Container": 114,
#           "Movement-ALT": 90,
#           "Movement-Subject": 72,
#           "Direction": 55,
#           "Dimensioning-Size": 45,
#           "Movement-Light": 38,
#           "Movement-Sound": 38,
#           "Dimensioning-Amount": 35,
#           "Place-Object": 32,
#           "Place-Object-MC": 14,
#           "Movement-Object": 11,
#           "Direction-ALT": 11,
#           "Place-ALT": 10,
#           "Positioning-ALT": 9,
#           "Dimensioning-Distance": 7,
#           "Place-Abstract": 7,
#           "Place-Container-MC": 7,
#           "Dimensioning-ALT": 5,
#           "Place-Abstract-MC": 1,
#           "Movement-Smell": 1
#         },
#         "TOTAL": {
#           "Movement-ALT": 162,
#           "Movement-Subject": 109,
#           "Direction": 90,
#           "Place-Container": 138,
#           "Movement-Sound": 58,
#           "Positioning": 141,
#           "Direction-ALT": 23,
#           "Place-Container-MC": 18,
#           "Dimensioning-Amount": 42,
#           "Place-ALT": 16,
#           "Dimensioning-Size": 51,
#           "Movement-Object": 17,
#           "Movement-Light": 43,
#           "Place-Object": 37,
#           "Dimensioning-ALT": 8,
#           "Positioning-ALT": 12,
#           "Dimensioning-Distance": 9,
#           "Place-Object-MC": 14,
#           "Place-Abstract": 7,
#           "Place-Abstract-MC": 1,
#           "Movement-Smell": 1
#         }
#       },
#       "TOTAL": {
#         "Movement-ALT": 576,
#         "Place-Container": 523,
#         "Movement-Subject": 508,
#         "Positioning": 507,
#         "Direction": 358,
#         "Movement-Sound": 309,
#         "Dimensioning-Amount": 164,
#         "Movement-Light": 146,
#         "Dimensioning-Size": 140,
#         "Place-Container-MC": 102,
#         "Direction-ALT": 86,
#         "Place-Object": 83,
#         "Place-ALT": 78,
#         "Movement-Object": 66,
#         "Dimensioning-ALT": 57,
#         "Dimensioning-Distance": 38,
#         "Positioning-ALT": 37,
#         "Place-Object-MC": 33,
#         "Place-Abstract": 24,
#         "Place-Abstract-MC": 5,
#         "Movement-Smell": 4
#       }
#     }
#   },
#   "amount_of_token": {
#     "cs1": {
#       "canspin-lat-19": {
#         "CANSpiN-lat-19_004_1.tsv": 1210,
#         "CANSpiN-lat-19_041_1.tsv": 1074,
#         "TOTAL": 2284
#       },
#       "canspin-deu-19": {
#         "CANSpiN-deu-19_001_1-1-1.tsv": 5491,
#         "CANSpiN-deu-19_030_1-1-1.tsv": 7179,
#         "TOTAL": 12670
#       },
#       "canspin-deu-20": {
#         "CANSpiN-deu-20_002_1_shuffled.tsv": 2689,
#         "CANSpiN-deu-20_021_1_shuffled.tsv": 744,
#         "TOTAL": 3433
#       },
#       "canspin-spa-19": {
#         "CANSpiN-spa-19_001_1.tsv": 1843,
#         "CANSpiN-spa-19_008_1.tsv": 4300,
#         "TOTAL": 6143
#       },
#       "TOTAL": 24530
#     }
#   },
#   "amount_of_annotated_token": {
#     "cs1": {
#       "canspin-lat-19": {
#         "CANSpiN-lat-19_004_1.tsv": 135,
#         "CANSpiN-lat-19_041_1.tsv": 205,
#         "TOTAL": 340
#       },
#       "canspin-deu-19": {
#         "CANSpiN-deu-19_001_1-1-1.tsv": 942,
#         "CANSpiN-deu-19_030_1-1-1.tsv": 1132,
#         "TOTAL": 2074
#       },
#       "canspin-deu-20": {
#         "CANSpiN-deu-20_002_1_shuffled.tsv": 446,
#         "CANSpiN-deu-20_021_1_shuffled.tsv": 161,
#         "TOTAL": 607
#       },
#       "canspin-spa-19": {
#         "CANSpiN-spa-19_001_1.tsv": 277,
#         "CANSpiN-spa-19_008_1.tsv": 775,
#         "TOTAL": 1052
#       },
#       "TOTAL": 4073
#     }
#   },
#   "amount_of_annotated_token_by_class": {
#     "cs1": {
#       "canspin-lat-19": {
#         "CANSpiN-lat-19_004_1.tsv": {
#           "Movement-ALT": 20,
#           "Movement-Subject": 19,
#           "Place-Container": 18,
#           "Positioning": 16,
#           "Dimensioning-Amount": 12,
#           "Movement-Object": 9,
#           "Movement-Sound": 8,
#           "Place-Container-MC": 8,
#           "Dimensioning-Size": 6,
#           "Direction": 5,
#           "Dimensioning-Distance": 5,
#           "Movement-Light": 4,
#           "Dimensioning-ALT": 2,
#           "Place-Object": 1,
#           "Direction-ALT": 1,
#           "Place-Object-MC": 1,
#           "Place-Abstract": 0,
#           "Place-Abstract-MC": 0,
#           "Place-ALT": 0,
#           "Movement-Smell": 0,
#           "Positioning-ALT": 0
#         },
#         "CANSpiN-lat-19_041_1.tsv": {
#           "Place-Container": 64,
#           "Positioning": 33,
#           "Movement-Subject": 29,
#           "Movement-ALT": 17,
#           "Direction": 13,
#           "Dimensioning-Amount": 10,
#           "Dimensioning-Size": 9,
#           "Place-Object": 6,
#           "Movement-Light": 4,
#           "Place-Container-MC": 4,
#           "Movement-Sound": 4,
#           "Place-ALT": 3,
#           "Positioning-ALT": 2,
#           "Dimensioning-Distance": 2,
#           "Movement-Object": 2,
#           "Dimensioning-ALT": 1,
#           "Direction-ALT": 1,
#           "Place-Abstract": 1,
#           "Place-Object-MC": 0,
#           "Place-Abstract-MC": 0,
#           "Movement-Smell": 0
#         },
#         "TOTAL": {
#           "Movement-ALT": 37,
#           "Movement-Subject": 48,
#           "Place-Container": 82,
#           "Positioning": 49,
#           "Dimensioning-Amount": 22,
#           "Movement-Object": 11,
#           "Movement-Sound": 12,
#           "Place-Container-MC": 12,
#           "Dimensioning-Size": 15,
#           "Direction": 18,
#           "Dimensioning-Distance": 7,
#           "Movement-Light": 8,
#           "Dimensioning-ALT": 3,
#           "Place-Object": 7,
#           "Direction-ALT": 2,
#           "Place-Object-MC": 1,
#           "Place-Abstract": 1,
#           "Place-Abstract-MC": 0,
#           "Place-ALT": 3,
#           "Movement-Smell": 0,
#           "Positioning-ALT": 2
#         }
#       },
#       "canspin-deu-19": {
#         "CANSpiN-deu-19_001_1-1-1.tsv": {
#           "Movement-Subject": 136,
#           "Place-Container": 131,
#           "Positioning": 120,
#           "Movement-ALT": 110,
#           "Movement-Sound": 100,
#           "Direction": 97,
#           "Dimensioning-Amount": 62,
#           "Movement-Light": 41,
#           "Dimensioning-Size": 34,
#           "Place-Container-MC": 32,
#           "Dimensioning-Distance": 16,
#           "Place-Object": 10,
#           "Place-Abstract": 10,
#           "Movement-Object": 10,
#           "Dimensioning-ALT": 10,
#           "Direction-ALT": 7,
#           "Place-Object-MC": 6,
#           "Place-ALT": 5,
#           "Positioning-ALT": 4,
#           "Place-Abstract-MC": 1,
#           "Movement-Smell": 0
#         },
#         "CANSpiN-deu-19_030_1-1-1.tsv": {
#           "Movement-ALT": 197,
#           "Movement-Subject": 138,
#           "Positioning": 137,
#           "Movement-Sound": 115,
#           "Place-Container": 91,
#           "Direction": 86,
#           "Movement-Light": 58,
#           "Dimensioning-Amount": 57,
#           "Dimensioning-Size": 38,
#           "Place-ALT": 37,
#           "Direction-ALT": 37,
#           "Dimensioning-ALT": 28,
#           "Movement-Object": 27,
#           "Place-Object": 25,
#           "Place-Container-MC": 20,
#           "Dimensioning-Distance": 14,
#           "Positioning-ALT": 12,
#           "Place-Object-MC": 8,
#           "Place-Abstract": 5,
#           "Place-Abstract-MC": 2,
#           "Movement-Smell": 0
#         },
#         "TOTAL": {
#           "Movement-Subject": 274,
#           "Place-Container": 222,
#           "Positioning": 257,
#           "Movement-ALT": 307,
#           "Movement-Sound": 215,
#           "Direction": 183,
#           "Dimensioning-Amount": 119,
#           "Movement-Light": 99,
#           "Dimensioning-Size": 72,
#           "Place-Container-MC": 52,
#           "Dimensioning-Distance": 30,
#           "Place-Object": 35,
#           "Place-Abstract": 15,
#           "Movement-Object": 37,
#           "Dimensioning-ALT": 38,
#           "Direction-ALT": 44,
#           "Place-Object-MC": 14,
#           "Place-ALT": 42,
#           "Positioning-ALT": 16,
#           "Place-Abstract-MC": 3,
#           "Movement-Smell": 0
#         }
#       },
#       "canspin-deu-20": {
#         "CANSpiN-deu-20_002_1_shuffled.tsv": {
#           "Movement-Subject": 86,
#           "Movement-ALT": 73,
#           "Direction": 54,
#           "Place-Container": 52,
#           "Movement-Sound": 47,
#           "Positioning": 42,
#           "Place-Container-MC": 17,
#           "Place-ALT": 15,
#           "Direction-ALT": 13,
#           "Dimensioning-Distance": 12,
#           "Positioning-ALT": 7,
#           "Dimensioning-ALT": 6,
#           "Movement-Light": 5,
#           "Dimensioning-Amount": 4,
#           "Movement-Smell": 3,
#           "Movement-Object": 3,
#           "Place-Object-MC": 2,
#           "Place-Object": 2,
#           "Dimensioning-Size": 1,
#           "Place-Abstract": 1,
#           "Place-Abstract-MC": 1
#         },
#         "CANSpiN-deu-20_021_1_shuffled.tsv": {
#           "Place-Container": 37,
#           "Movement-Subject": 29,
#           "Positioning": 22,
#           "Movement-ALT": 21,
#           "Direction": 16,
#           "Dimensioning-Size": 6,
#           "Movement-Light": 5,
#           "Direction-ALT": 4,
#           "Place-Container-MC": 4,
#           "Dimensioning-Distance": 3,
#           "Movement-Object": 3,
#           "Dimensioning-Amount": 2,
#           "Place-ALT": 2,
#           "Place-Object": 2,
#           "Place-Object-MC": 2,
#           "Dimensioning-ALT": 2,
#           "Movement-Sound": 1,
#           "Place-Abstract": 0,
#           "Place-Abstract-MC": 0,
#           "Movement-Smell": 0,
#           "Positioning-ALT": 0
#         },
#         "TOTAL": {
#           "Movement-Subject": 115,
#           "Movement-ALT": 94,
#           "Direction": 70,
#           "Place-Container": 89,
#           "Movement-Sound": 48,
#           "Positioning": 64,
#           "Place-Container-MC": 21,
#           "Place-ALT": 17,
#           "Direction-ALT": 17,
#           "Dimensioning-Distance": 15,
#           "Positioning-ALT": 7,
#           "Dimensioning-ALT": 8,
#           "Movement-Light": 10,
#           "Dimensioning-Amount": 6,
#           "Movement-Smell": 3,
#           "Movement-Object": 6,
#           "Place-Object-MC": 4,
#           "Place-Object": 4,
#           "Dimensioning-Size": 7,
#           "Place-Abstract": 1,
#           "Place-Abstract-MC": 1
#         }
#       },
#       "canspin-spa-19": {
#         "CANSpiN-spa-19_001_1.tsv": {
#           "Movement-ALT": 72,
#           "Movement-Subject": 38,
#           "Direction": 35,
#           "Place-Container": 26,
#           "Movement-Sound": 20,
#           "Positioning": 15,
#           "Direction-ALT": 12,
#           "Place-Container-MC": 11,
#           "Dimensioning-Distance": 7,
#           "Dimensioning-Amount": 7,
#           "Dimensioning-Size": 6,
#           "Place-ALT": 6,
#           "Movement-Object": 6,
#           "Place-Object": 5,
#           "Movement-Light": 5,
#           "Dimensioning-ALT": 3,
#           "Positioning-ALT": 3,
#           "Place-Object-MC": 0,
#           "Place-Abstract": 0,
#           "Place-Abstract-MC": 0,
#           "Movement-Smell": 0
#         },
#         "CANSpiN-spa-19_008_1.tsv": {
#           "Positioning": 142,
#           "Place-Container": 117,
#           "Movement-ALT": 90,
#           "Movement-Subject": 72,
#           "Dimensioning-Size": 61,
#           "Direction": 58,
#           "Movement-Light": 39,
#           "Movement-Sound": 38,
#           "Dimensioning-Amount": 35,
#           "Place-Object": 32,
#           "Place-Object-MC": 14,
#           "Dimensioning-Distance": 13,
#           "Movement-Object": 12,
#           "Direction-ALT": 11,
#           "Place-ALT": 10,
#           "Positioning-ALT": 10,
#           "Place-Abstract": 7,
#           "Place-Container-MC": 7,
#           "Dimensioning-ALT": 5,
#           "Place-Abstract-MC": 1,
#           "Movement-Smell": 1
#         },
#         "TOTAL": {
#           "Movement-ALT": 162,
#           "Movement-Subject": 110,
#           "Direction": 93,
#           "Place-Container": 143,
#           "Movement-Sound": 58,
#           "Positioning": 157,
#           "Direction-ALT": 23,
#           "Place-Container-MC": 18,
#           "Dimensioning-Distance": 20,
#           "Dimensioning-Amount": 42,
#           "Dimensioning-Size": 67,
#           "Place-ALT": 16,
#           "Movement-Object": 18,
#           "Place-Object": 37,
#           "Movement-Light": 44,
#           "Dimensioning-ALT": 8,
#           "Positioning-ALT": 13,
#           "Place-Object-MC": 14,
#           "Place-Abstract": 7,
#           "Place-Abstract-MC": 1,
#           "Movement-Smell": 1
#         }
#       },
#       "TOTAL": {
#         "Movement-ALT": 600,
#         "Movement-Subject": 547,
#         "Place-Container": 536,
#         "Positioning": 527,
#         "Direction": 364,
#         "Movement-Sound": 333,
#         "Dimensioning-Amount": 189,
#         "Dimensioning-Size": 161,
#         "Movement-Light": 161,
#         "Place-Container-MC": 103,
#         "Direction-ALT": 86,
#         "Place-Object": 83,
#         "Place-ALT": 78,
#         "Movement-Object": 72,
#         "Dimensioning-Distance": 72,
#         "Dimensioning-ALT": 57,
#         "Positioning-ALT": 38,
#         "Place-Object-MC": 33,
#         "Place-Abstract": 24,
#         "Place-Abstract-MC": 5,
#         "Movement-Smell": 4
#       }
#     }
#   },
#   "ratios": {
#     "cs1": {
#       "canspin-lat-19": {
#         "CANSpiN-lat-19_004_1.tsv": {
#           "token_of_file:total_token_amount_in_corpus": 0.5297,
#           "annotated_token_by_class_in_file:annotated_token_by_class_in_corpus": {
#             "Movement-ALT": 0.5405,
#             "Movement-Subject": 0.3958,
#             "Place-Container": 0.2195,
#             "Positioning": 0.3265,
#             "Dimensioning-Amount": 0.5454,
#             "Movement-Object": 0.8181,
#             "Movement-Sound": 0.6666,
#             "Place-Container-MC": 0.6666,
#             "Dimensioning-Size": 0.4,
#             "Direction": 0.2777,
#             "Dimensioning-Distance": 0.7142,
#             "Movement-Light": 0.5,
#             "Dimensioning-ALT": 0.6666,
#             "Place-Object": 0.1428,
#             "Direction-ALT": 0.5,
#             "Place-Object-MC": 1.0,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0,
#             "TOTAL": 0.397
#           },
#           "annotated_token_by_class_in_file:total_token_amount_in_file": {
#             "Movement-ALT": 0.0165,
#             "Movement-Subject": 0.0157,
#             "Place-Container": 0.0148,
#             "Positioning": 0.0132,
#             "Dimensioning-Amount": 0.0099,
#             "Movement-Object": 0.0074,
#             "Movement-Sound": 0.0066,
#             "Place-Container-MC": 0.0066,
#             "Dimensioning-Size": 0.0049,
#             "Direction": 0.0041,
#             "Dimensioning-Distance": 0.0041,
#             "Movement-Light": 0.0033,
#             "Dimensioning-ALT": 0.0016,
#             "Place-Object": 0.0008,
#             "Direction-ALT": 0.0008,
#             "Place-Object-MC": 0.0008,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0,
#             "TOTAL": 0.1115
#           },
#           "annotated_token_by_class_in_file:total_annotated_token_amount_in_file": {
#             "Movement-ALT": 0.1481,
#             "Movement-Subject": 0.1407,
#             "Place-Container": 0.1333,
#             "Positioning": 0.1185,
#             "Dimensioning-Amount": 0.0888,
#             "Movement-Object": 0.0666,
#             "Movement-Sound": 0.0592,
#             "Place-Container-MC": 0.0592,
#             "Dimensioning-Size": 0.0444,
#             "Direction": 0.037,
#             "Dimensioning-Distance": 0.037,
#             "Movement-Light": 0.0296,
#             "Dimensioning-ALT": 0.0148,
#             "Place-Object": 0.0074,
#             "Direction-ALT": 0.0074,
#             "Place-Object-MC": 0.0074,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0
#           },
#           "annotations_by_class_in_file:annotations_by_class_in_corpus": {
#             "Movement-ALT": 0.5405,
#             "Movement-Subject": 0.3958,
#             "Place-Container": 0.2105,
#             "Positioning": 0.3265,
#             "Dimensioning-Amount": 0.5,
#             "Movement-Object": 0.8181,
#             "Movement-Sound": 0.6666,
#             "Place-Container-MC": 0.6363,
#             "Dimensioning-Size": 0.4285,
#             "Direction": 0.2941,
#             "Movement-Light": 0.5,
#             "Dimensioning-Distance": 0.6,
#             "Dimensioning-ALT": 0.6666,
#             "Place-Object": 0.1428,
#             "Direction-ALT": 0.5,
#             "Place-Object-MC": 1.0,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0,
#             "TOTAL": 0.3914
#           },
#           "annotations_by_class_in_file:total_token_amount_in_file": {
#             "Movement-ALT": 0.0165,
#             "Movement-Subject": 0.0157,
#             "Place-Container": 0.0132,
#             "Positioning": 0.0132,
#             "Dimensioning-Amount": 0.0082,
#             "Movement-Object": 0.0074,
#             "Movement-Sound": 0.0066,
#             "Place-Container-MC": 0.0057,
#             "Dimensioning-Size": 0.0049,
#             "Direction": 0.0041,
#             "Movement-Light": 0.0033,
#             "Dimensioning-Distance": 0.0024,
#             "Dimensioning-ALT": 0.0016,
#             "Place-Object": 0.0008,
#             "Direction-ALT": 0.0008,
#             "Place-Object-MC": 0.0008,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0,
#             "TOTAL": 0.1057
#           },
#           "annotations_by_class_in_file:total_annotations_amount_in_file": {
#             "Movement-ALT": 0.1562,
#             "Movement-Subject": 0.1484,
#             "Place-Container": 0.125,
#             "Positioning": 0.125,
#             "Dimensioning-Amount": 0.0781,
#             "Movement-Object": 0.0703,
#             "Movement-Sound": 0.0625,
#             "Place-Container-MC": 0.0546,
#             "Dimensioning-Size": 0.0468,
#             "Direction": 0.039,
#             "Movement-Light": 0.0312,
#             "Dimensioning-Distance": 0.0234,
#             "Dimensioning-ALT": 0.0156,
#             "Place-Object": 0.0078,
#             "Direction-ALT": 0.0078,
#             "Place-Object-MC": 0.0078,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0
#           }
#         },
#         "CANSpiN-lat-19_041_1.tsv": {
#           "token_of_file:total_token_amount_in_corpus": 0.4702,
#           "annotated_token_by_class_in_file:annotated_token_by_class_in_corpus": {
#             "Movement-ALT": 0.4594,
#             "Movement-Subject": 0.6041,
#             "Place-Container": 0.7804,
#             "Positioning": 0.6734,
#             "Dimensioning-Amount": 0.4545,
#             "Movement-Object": 0.1818,
#             "Movement-Sound": 0.3333,
#             "Place-Container-MC": 0.3333,
#             "Dimensioning-Size": 0.6,
#             "Direction": 0.7222,
#             "Dimensioning-Distance": 0.2857,
#             "Movement-Light": 0.5,
#             "Dimensioning-ALT": 0.3333,
#             "Place-Object": 0.8571,
#             "Direction-ALT": 0.5,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract": 1.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 1.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 1.0,
#             "TOTAL": 0.6029
#           },
#           "annotated_token_by_class_in_file:total_token_amount_in_file": {
#             "Place-Container": 0.0595,
#             "Positioning": 0.0307,
#             "Movement-Subject": 0.027,
#             "Movement-ALT": 0.0158,
#             "Direction": 0.0121,
#             "Dimensioning-Amount": 0.0093,
#             "Dimensioning-Size": 0.0083,
#             "Place-Object": 0.0055,
#             "Movement-Light": 0.0037,
#             "Place-Container-MC": 0.0037,
#             "Movement-Sound": 0.0037,
#             "Place-ALT": 0.0027,
#             "Positioning-ALT": 0.0018,
#             "Dimensioning-Distance": 0.0018,
#             "Movement-Object": 0.0018,
#             "Dimensioning-ALT": 0.0009,
#             "Direction-ALT": 0.0009,
#             "Place-Abstract": 0.0009,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.1908
#           },
#           "annotated_token_by_class_in_file:total_annotated_token_amount_in_file": {
#             "Place-Container": 0.3121,
#             "Positioning": 0.1609,
#             "Movement-Subject": 0.1414,
#             "Movement-ALT": 0.0829,
#             "Direction": 0.0634,
#             "Dimensioning-Amount": 0.0487,
#             "Dimensioning-Size": 0.0439,
#             "Place-Object": 0.0292,
#             "Movement-Light": 0.0195,
#             "Place-Container-MC": 0.0195,
#             "Movement-Sound": 0.0195,
#             "Place-ALT": 0.0146,
#             "Positioning-ALT": 0.0097,
#             "Dimensioning-Distance": 0.0097,
#             "Movement-Object": 0.0097,
#             "Dimensioning-ALT": 0.0048,
#             "Direction-ALT": 0.0048,
#             "Place-Abstract": 0.0048,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Movement-Smell": 0.0
#           },
#           "annotations_by_class_in_file:annotations_by_class_in_corpus": {
#             "Movement-ALT": 0.4594,
#             "Movement-Subject": 0.6041,
#             "Place-Container": 0.7894,
#             "Positioning": 0.6734,
#             "Dimensioning-Amount": 0.5,
#             "Movement-Object": 0.1818,
#             "Movement-Sound": 0.3333,
#             "Place-Container-MC": 0.3636,
#             "Dimensioning-Size": 0.5714,
#             "Direction": 0.7058,
#             "Movement-Light": 0.5,
#             "Dimensioning-Distance": 0.4,
#             "Dimensioning-ALT": 0.3333,
#             "Place-Object": 0.8571,
#             "Direction-ALT": 0.5,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract": 1.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 1.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 1.0,
#             "TOTAL": 0.6085
#           },
#           "annotations_by_class_in_file:total_token_amount_in_file": {
#             "Place-Container": 0.0558,
#             "Positioning": 0.0307,
#             "Movement-Subject": 0.027,
#             "Movement-ALT": 0.0158,
#             "Direction": 0.0111,
#             "Dimensioning-Amount": 0.0093,
#             "Dimensioning-Size": 0.0074,
#             "Place-Object": 0.0055,
#             "Movement-Light": 0.0037,
#             "Place-Container-MC": 0.0037,
#             "Movement-Sound": 0.0037,
#             "Place-ALT": 0.0027,
#             "Positioning-ALT": 0.0018,
#             "Dimensioning-Distance": 0.0018,
#             "Movement-Object": 0.0018,
#             "Dimensioning-ALT": 0.0009,
#             "Direction-ALT": 0.0009,
#             "Place-Abstract": 0.0009,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.1852
#           },
#           "annotations_by_class_in_file:total_annotations_amount_in_file": {
#             "Place-Container": 0.3015,
#             "Positioning": 0.1658,
#             "Movement-Subject": 0.1457,
#             "Movement-ALT": 0.0854,
#             "Direction": 0.0603,
#             "Dimensioning-Amount": 0.0502,
#             "Dimensioning-Size": 0.0402,
#             "Place-Object": 0.0301,
#             "Movement-Light": 0.0201,
#             "Place-Container-MC": 0.0201,
#             "Movement-Sound": 0.0201,
#             "Place-ALT": 0.015,
#             "Positioning-ALT": 0.01,
#             "Dimensioning-Distance": 0.01,
#             "Movement-Object": 0.01,
#             "Dimensioning-ALT": 0.005,
#             "Direction-ALT": 0.005,
#             "Place-Abstract": 0.005,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Movement-Smell": 0.0
#           }
#         },
#         "TOTAL": {
#           "token_of_corpus:total_token_amount_in_schema": 0.0931,
#           "annotated_token_by_class_in_corpus:annotated_token_by_class_in_schema": {
#             "Movement-ALT": 0.1859,
#             "Movement-Subject": 0.3037,
#             "Place-Container": 0.3644,
#             "Positioning": 0.2378,
#             "Dimensioning-Amount": 0.3437,
#             "Movement-Object": 0.3793,
#             "Movement-Sound": 0.1714,
#             "Place-Container-MC": 0.4,
#             "Dimensioning-Size": 0.1829,
#             "Direction": 0.1621,
#             "Dimensioning-Distance": 0.2592,
#             "Movement-Light": 0.1538,
#             "Dimensioning-ALT": 0.2727,
#             "Place-Object": 0.159,
#             "Direction-ALT": 0.08,
#             "Place-Object-MC": 0.0666,
#             "Place-Abstract": 0.125,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.1578,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.1333,
#             "TOTAL": 0.0834
#           },
#           "annotated_token_by_class_in_corpus:total_token_amount_in_corpus": {
#             "Movement-ALT": 0.0161,
#             "Movement-Subject": 0.021,
#             "Place-Container": 0.0359,
#             "Positioning": 0.0214,
#             "Dimensioning-Amount": 0.0096,
#             "Movement-Object": 0.0048,
#             "Movement-Sound": 0.0052,
#             "Place-Container-MC": 0.0052,
#             "Dimensioning-Size": 0.0065,
#             "Direction": 0.0078,
#             "Dimensioning-Distance": 0.003,
#             "Movement-Light": 0.0035,
#             "Dimensioning-ALT": 0.0013,
#             "Place-Object": 0.003,
#             "Direction-ALT": 0.0008,
#             "Place-Object-MC": 0.0004,
#             "Place-Abstract": 0.0004,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0013,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0008,
#             "TOTAL": 0.1488
#           },
#           "annotated_token_by_class_in_corpus:total_annotated_token_amount_in_corpus": {
#             "Movement-ALT": 0.1088,
#             "Movement-Subject": 0.1411,
#             "Place-Container": 0.2411,
#             "Positioning": 0.1441,
#             "Dimensioning-Amount": 0.0647,
#             "Movement-Object": 0.0323,
#             "Movement-Sound": 0.0352,
#             "Place-Container-MC": 0.0352,
#             "Dimensioning-Size": 0.0441,
#             "Direction": 0.0529,
#             "Dimensioning-Distance": 0.0205,
#             "Movement-Light": 0.0235,
#             "Dimensioning-ALT": 0.0088,
#             "Place-Object": 0.0205,
#             "Direction-ALT": 0.0058,
#             "Place-Object-MC": 0.0029,
#             "Place-Abstract": 0.0029,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0088,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0058
#           },
#           "annotations_by_class_in_corpus:annotations_by_class_in_schema": {
#             "Movement-ALT": 0.1859,
#             "Movement-Subject": 0.3057,
#             "Place-Container": 0.3551,
#             "Positioning": 0.2578,
#             "Dimensioning-Amount": 0.3225,
#             "Movement-Object": 0.3928,
#             "Movement-Sound": 0.1714,
#             "Place-Container-MC": 0.3793,
#             "Dimensioning-Size": 0.2153,
#             "Direction": 0.1588,
#             "Movement-Light": 0.1568,
#             "Dimensioning-Distance": 0.3571,
#             "Dimensioning-ALT": 0.2727,
#             "Place-Object": 0.159,
#             "Direction-ALT": 0.08,
#             "Place-Object-MC": 0.0666,
#             "Place-Abstract": 0.125,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.1578,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.1428,
#             "TOTAL": 0.085
#           },
#           "annotations_by_class_in_corpus:total_token_amount_in_corpus": {
#             "Movement-ALT": 0.0161,
#             "Movement-Subject": 0.021,
#             "Place-Container": 0.0332,
#             "Positioning": 0.0214,
#             "Dimensioning-Amount": 0.0087,
#             "Movement-Object": 0.0048,
#             "Movement-Sound": 0.0052,
#             "Place-Container-MC": 0.0048,
#             "Dimensioning-Size": 0.0061,
#             "Direction": 0.0074,
#             "Movement-Light": 0.0035,
#             "Dimensioning-Distance": 0.0021,
#             "Dimensioning-ALT": 0.0013,
#             "Place-Object": 0.003,
#             "Direction-ALT": 0.0008,
#             "Place-Object-MC": 0.0004,
#             "Place-Abstract": 0.0004,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0013,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0008,
#             "TOTAL": 0.1431
#           },
#           "annotations_by_class_in_corpus:total_annotations_amount_in_corpus": {
#             "Movement-ALT": 0.1131,
#             "Movement-Subject": 0.1467,
#             "Place-Container": 0.2324,
#             "Positioning": 0.1498,
#             "Dimensioning-Amount": 0.0611,
#             "Movement-Object": 0.0336,
#             "Movement-Sound": 0.0366,
#             "Place-Container-MC": 0.0336,
#             "Dimensioning-Size": 0.0428,
#             "Direction": 0.0519,
#             "Movement-Light": 0.0244,
#             "Dimensioning-Distance": 0.0152,
#             "Dimensioning-ALT": 0.0091,
#             "Place-Object": 0.0214,
#             "Direction-ALT": 0.0061,
#             "Place-Object-MC": 0.003,
#             "Place-Abstract": 0.003,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0091,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0061
#           }
#         }
#       },
#       "canspin-deu-19": {
#         "CANSpiN-deu-19_001_1-1-1.tsv": {
#           "token_of_file:total_token_amount_in_corpus": 0.4333,
#           "annotated_token_by_class_in_file:annotated_token_by_class_in_corpus": {
#             "Movement-Subject": 0.4963,
#             "Place-Container": 0.59,
#             "Positioning": 0.4669,
#             "Movement-ALT": 0.3583,
#             "Movement-Sound": 0.4651,
#             "Direction": 0.53,
#             "Dimensioning-Amount": 0.521,
#             "Movement-Light": 0.4141,
#             "Dimensioning-Size": 0.4722,
#             "Place-Container-MC": 0.6153,
#             "Dimensioning-Distance": 0.5333,
#             "Place-Object": 0.2857,
#             "Place-Abstract": 0.6666,
#             "Movement-Object": 0.2702,
#             "Dimensioning-ALT": 0.2631,
#             "Direction-ALT": 0.159,
#             "Place-Object-MC": 0.4285,
#             "Place-ALT": 0.119,
#             "Positioning-ALT": 0.25,
#             "Place-Abstract-MC": 0.3333,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.4541
#           },
#           "annotated_token_by_class_in_file:total_token_amount_in_file": {
#             "Movement-Subject": 0.0247,
#             "Place-Container": 0.0238,
#             "Positioning": 0.0218,
#             "Movement-ALT": 0.02,
#             "Movement-Sound": 0.0182,
#             "Direction": 0.0176,
#             "Dimensioning-Amount": 0.0112,
#             "Movement-Light": 0.0074,
#             "Dimensioning-Size": 0.0061,
#             "Place-Container-MC": 0.0058,
#             "Dimensioning-Distance": 0.0029,
#             "Place-Object": 0.0018,
#             "Place-Abstract": 0.0018,
#             "Movement-Object": 0.0018,
#             "Dimensioning-ALT": 0.0018,
#             "Direction-ALT": 0.0012,
#             "Place-Object-MC": 0.001,
#             "Place-ALT": 0.0009,
#             "Positioning-ALT": 0.0007,
#             "Place-Abstract-MC": 0.0001,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.1715
#           },
#           "annotated_token_by_class_in_file:total_annotated_token_amount_in_file": {
#             "Movement-Subject": 0.1443,
#             "Place-Container": 0.139,
#             "Positioning": 0.1273,
#             "Movement-ALT": 0.1167,
#             "Movement-Sound": 0.1061,
#             "Direction": 0.1029,
#             "Dimensioning-Amount": 0.0658,
#             "Movement-Light": 0.0435,
#             "Dimensioning-Size": 0.036,
#             "Place-Container-MC": 0.0339,
#             "Dimensioning-Distance": 0.0169,
#             "Place-Object": 0.0106,
#             "Place-Abstract": 0.0106,
#             "Movement-Object": 0.0106,
#             "Dimensioning-ALT": 0.0106,
#             "Direction-ALT": 0.0074,
#             "Place-Object-MC": 0.0063,
#             "Place-ALT": 0.0053,
#             "Positioning-ALT": 0.0042,
#             "Place-Abstract-MC": 0.001,
#             "Movement-Smell": 0.0
#           },
#           "annotations_by_class_in_file:annotations_by_class_in_corpus": {
#             "Place-Container": 0.59,
#             "Movement-Subject": 0.508,
#             "Positioning": 0.4743,
#             "Movement-ALT": 0.3595,
#             "Direction": 0.5248,
#             "Movement-Sound": 0.4742,
#             "Dimensioning-Amount": 0.5416,
#             "Movement-Light": 0.4069,
#             "Dimensioning-Size": 0.4782,
#             "Place-Container-MC": 0.6153,
#             "Dimensioning-Distance": 0.6818,
#             "Place-Object": 0.2857,
#             "Place-Abstract": 0.6666,
#             "Dimensioning-ALT": 0.2631,
#             "Movement-Object": 0.2812,
#             "Direction-ALT": 0.159,
#             "Place-Object-MC": 0.4285,
#             "Place-ALT": 0.119,
#             "Positioning-ALT": 0.25,
#             "Place-Abstract-MC": 0.3333,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.4595
#           },
#           "annotations_by_class_in_file:total_token_amount_in_file": {
#             "Place-Container": 0.0238,
#             "Movement-Subject": 0.0229,
#             "Positioning": 0.0218,
#             "Movement-ALT": 0.0191,
#             "Direction": 0.0173,
#             "Movement-Sound": 0.0167,
#             "Dimensioning-Amount": 0.0094,
#             "Movement-Light": 0.0063,
#             "Dimensioning-Size": 0.006,
#             "Place-Container-MC": 0.0058,
#             "Dimensioning-Distance": 0.0027,
#             "Place-Object": 0.0018,
#             "Place-Abstract": 0.0018,
#             "Dimensioning-ALT": 0.0018,
#             "Movement-Object": 0.0016,
#             "Direction-ALT": 0.0012,
#             "Place-Object-MC": 0.001,
#             "Place-ALT": 0.0009,
#             "Positioning-ALT": 0.0007,
#             "Place-Abstract-MC": 0.0001,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.1635
#           },
#           "annotations_by_class_in_file:total_annotations_amount_in_file": {
#             "Place-Container": 0.1458,
#             "Movement-Subject": 0.1403,
#             "Positioning": 0.1336,
#             "Movement-ALT": 0.1169,
#             "Direction": 0.1057,
#             "Movement-Sound": 0.1024,
#             "Dimensioning-Amount": 0.0579,
#             "Movement-Light": 0.0389,
#             "Dimensioning-Size": 0.0367,
#             "Place-Container-MC": 0.0356,
#             "Dimensioning-Distance": 0.0167,
#             "Place-Object": 0.0111,
#             "Place-Abstract": 0.0111,
#             "Dimensioning-ALT": 0.0111,
#             "Movement-Object": 0.01,
#             "Direction-ALT": 0.0077,
#             "Place-Object-MC": 0.0066,
#             "Place-ALT": 0.0055,
#             "Positioning-ALT": 0.0044,
#             "Place-Abstract-MC": 0.0011,
#             "Movement-Smell": 0.0
#           }
#         },
#         "CANSpiN-deu-19_030_1-1-1.tsv": {
#           "token_of_file:total_token_amount_in_corpus": 0.5666,
#           "annotated_token_by_class_in_file:annotated_token_by_class_in_corpus": {
#             "Movement-Subject": 0.5036,
#             "Place-Container": 0.4099,
#             "Positioning": 0.533,
#             "Movement-ALT": 0.6416,
#             "Movement-Sound": 0.5348,
#             "Direction": 0.4699,
#             "Dimensioning-Amount": 0.4789,
#             "Movement-Light": 0.5858,
#             "Dimensioning-Size": 0.5277,
#             "Place-Container-MC": 0.3846,
#             "Dimensioning-Distance": 0.4666,
#             "Place-Object": 0.7142,
#             "Place-Abstract": 0.3333,
#             "Movement-Object": 0.7297,
#             "Dimensioning-ALT": 0.7368,
#             "Direction-ALT": 0.8409,
#             "Place-Object-MC": 0.5714,
#             "Place-ALT": 0.8809,
#             "Positioning-ALT": 0.75,
#             "Place-Abstract-MC": 0.6666,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.5458
#           },
#           "annotated_token_by_class_in_file:total_token_amount_in_file": {
#             "Movement-ALT": 0.0274,
#             "Movement-Subject": 0.0192,
#             "Positioning": 0.019,
#             "Movement-Sound": 0.016,
#             "Place-Container": 0.0126,
#             "Direction": 0.0119,
#             "Movement-Light": 0.008,
#             "Dimensioning-Amount": 0.0079,
#             "Dimensioning-Size": 0.0052,
#             "Place-ALT": 0.0051,
#             "Direction-ALT": 0.0051,
#             "Dimensioning-ALT": 0.0039,
#             "Movement-Object": 0.0037,
#             "Place-Object": 0.0034,
#             "Place-Container-MC": 0.0027,
#             "Dimensioning-Distance": 0.0019,
#             "Positioning-ALT": 0.0016,
#             "Place-Object-MC": 0.0011,
#             "Place-Abstract": 0.0006,
#             "Place-Abstract-MC": 0.0002,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.1576
#           },
#           "annotated_token_by_class_in_file:total_annotated_token_amount_in_file": {
#             "Movement-ALT": 0.174,
#             "Movement-Subject": 0.1219,
#             "Positioning": 0.121,
#             "Movement-Sound": 0.1015,
#             "Place-Container": 0.0803,
#             "Direction": 0.0759,
#             "Movement-Light": 0.0512,
#             "Dimensioning-Amount": 0.0503,
#             "Dimensioning-Size": 0.0335,
#             "Place-ALT": 0.0326,
#             "Direction-ALT": 0.0326,
#             "Dimensioning-ALT": 0.0247,
#             "Movement-Object": 0.0238,
#             "Place-Object": 0.022,
#             "Place-Container-MC": 0.0176,
#             "Dimensioning-Distance": 0.0123,
#             "Positioning-ALT": 0.0106,
#             "Place-Object-MC": 0.007,
#             "Place-Abstract": 0.0044,
#             "Place-Abstract-MC": 0.0017,
#             "Movement-Smell": 0.0
#           },
#           "annotations_by_class_in_file:annotations_by_class_in_corpus": {
#             "Place-Container": 0.4099,
#             "Movement-Subject": 0.4919,
#             "Positioning": 0.5256,
#             "Movement-ALT": 0.6404,
#             "Direction": 0.4751,
#             "Movement-Sound": 0.5257,
#             "Dimensioning-Amount": 0.4583,
#             "Movement-Light": 0.593,
#             "Dimensioning-Size": 0.5217,
#             "Place-Container-MC": 0.3846,
#             "Dimensioning-Distance": 0.3181,
#             "Place-Object": 0.7142,
#             "Place-Abstract": 0.3333,
#             "Dimensioning-ALT": 0.7368,
#             "Movement-Object": 0.7187,
#             "Direction-ALT": 0.8409,
#             "Place-Object-MC": 0.5714,
#             "Place-ALT": 0.8809,
#             "Positioning-ALT": 0.75,
#             "Place-Abstract-MC": 0.6666,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.5404
#           },
#           "annotations_by_class_in_file:total_token_amount_in_file": {
#             "Movement-ALT": 0.026,
#             "Positioning": 0.0185,
#             "Movement-Subject": 0.0169,
#             "Movement-Sound": 0.0142,
#             "Place-Container": 0.0126,
#             "Direction": 0.0119,
#             "Movement-Light": 0.0071,
#             "Dimensioning-Amount": 0.0061,
#             "Direction-ALT": 0.0051,
#             "Place-ALT": 0.0051,
#             "Dimensioning-Size": 0.005,
#             "Dimensioning-ALT": 0.0039,
#             "Place-Object": 0.0034,
#             "Movement-Object": 0.0032,
#             "Place-Container-MC": 0.0027,
#             "Positioning-ALT": 0.0016,
#             "Place-Object-MC": 0.0011,
#             "Dimensioning-Distance": 0.0009,
#             "Place-Abstract": 0.0006,
#             "Place-Abstract-MC": 0.0002,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.147
#           },
# ...
#           "ankam": 1,
#           "bringt": 1,
#           "biertrinkende": 1,
#           "gesucht": 1,
#           "einlaufen": 1,
#           "hinunterrenne": 1,
#           "abstellen": 1,
#           "herauszugeben": 1,
#           "rutschte": 1,
#           "zusammen": 1,
#           "abgefahren": 1,
#           "öffnete": 1,
#           "zitiert": 1,
#           "schminkte": 1,
#           "aufsuchte": 1,
#           "hängte": 1,
#           "verteilte": 1,
#           "führte": 1,
#           "kauerte": 1,
#           "kniete": 1,
#           "wies": 1,
#           "gewaschen": 1,
#           "kaufte": 1,
#           "rieb": 1,
#           "ein": 1,
#           "vorfuhr": 1,
#           "verkaufte": 1,
#           "wischte": 1,
#           "wandte": 1,
#           "verschenken": 1,
#           "putzte": 1,
#           "legte": 1,
#           "bog": 1,
#           "verlassen": 1,
#           "hockte": 1
#         },
#         "Movement-ALT": {
#           "kam": 3,
#           "caer": 2,
#           "presentaba": 2,
#           "dar": 2,
#           "hace": 2,
#           "servía": 2,
#           "durchschneiden": 2,
#           "haben": 2,
#           "übergelaufen": 2,
#           "machte": 2,
#           "zeigten": 2,
#           "hielt": 2,
#           "aus": 2,
#           "llevaba": 1,
#           "haciendo": 1,
#           "batió": 1,
#           "caía": 1,
#           "constituiría": 1,
#           "avisado": 1,
#           "recibido": 1,
#           "conviene": 1,
#           "encontrar": 1,
#           "acercarnos": 1,
#           "envolver": 1,
#           "dado": 1,
#           "arrancarles": 1,
#           "murmuró": 1,
#           "llegará": 1,
#           "Parecía": 1,
#           "Tenía": 1,
#           "brillaban": 1,
#           "encadenarlo": 1,
#           "ardía": 1,
#           "corrido": 1,
#           "apegados": 1,
#           "volvían": 1,
#           "alejaban": 1,
#           "radiante": 1,
#           "devorados": 1,
#           "extiende": 1,
#           "cubriendo": 1,
#           "obcecados": 1,
#           "cubren": 1,
#           "abierta": 1,
#           "alzan": 1,
#           "sembrados": 1,
#           "volvieron": 1,
#           "perdido": 1,
#           "repartían": 1,
#           "reunía": 1,
#           "borrar": 1,
#           "revelaba": 1,
#           "Frisaba": 1,
#           "señalado": 1,
#           "daban": 1,
#           "entreverando": 1,
#           "tirada": 1,
#           "tiene": 1,
#           "ponga": 1,
#           "trates": 1,
#           "encaminadas": 1,
#           "diese": 1,
#           "dejase": 1,
#           "miraría": 1,
#           "pagar": 1,
#           "Encendióse": 1,
#           "pagaba": 1,
#           "parar": 1,
#           "pedido": 1,
#           "andado": 1,
#           "expuesto": 1,
#           "obligados": 1,
#           "digo": 1,
#           "tener": 1,
#           "lleva": 1,
#           "mostrado": 1,
#           "obligado": 1,
#           "soltado": 1,
#           "tengo": 1,
#           "hecho": 1,
#           "tratase": 1,
#           "cautiva": 1,
#           "hacerlo": 1,
#           "descaminado": 1,
#           "vas": 1,
#           "sumergida": 1,
#           "elevaba": 1,
#           "destacaba": 1,
#           "servir": 1,
#           "atravesaba": 1,
#           "perdía": 1,
#           "decir": 1,
#           "surcada": 1,
#           "impresiona": 1,
#           "lucía": 1,
#           "Llamábase": 1,
#           "encargado": 1,
#           "encuentran": 1,
#           "convenía": 1,
#           "finden": 1,
#           "unterbricht": 1,
#           "bergen": 1,
#           "winden": 1,
#           "versteckten": 1,
#           "verliert": 1,
#           "verwandelt": 1,
#           "zurückgezogen": 1,
#           "zerlöcherte": 1,
#           "besetzte": 1,
#           "zerknickte": 1,
#           "bedeckte": 1,
#           "zerbrochen": 1,
#           "steckenden": 1,
#           "verlieren": 1,
#           "gehaltene": 1,
#           "führte": 1,
#           "durchschnittenen": 1,
#           "beschrieb": 1,
#           "hält": 1,
#           "schien": 1,
#           "Fragend": 1,
#           "bekommen": 1,
#           "verlorene": 1,
#           "führt": 1,
#           "geht": 1,
#           "gerufen": 1,
#           "herabgekommen": 1,
#           "gegrüßt": 1,
#           "ziehen": 1,
#           "erhebt": 1,
#           "wäscht": 1,
#           "verschwinden": 1,
#           "verbirgt": 1,
#           "schwebendem": 1,
#           "Zug": 1,
#           "angerufen": 1,
#           "abgeben": 1,
#           "geben": 1,
#           "raus": 1,
#           "gemacht": 1,
#           "vor": 1,
#           "unterlaufen": 1,
#           "hielten": 1,
#           "verfalle": 1,
#           "annehmen": 1,
#           "hatte": 1,
#           "nannten": 1,
#           "verlassen": 1,
#           "machen": 1,
#           "her": 1,
#           "hört": 1,
#           "legen": 1,
#           "getrennt": 1,
#           "bedankte": 1,
#           "bemerken": 1,
#           "gelang": 1,
#           "brachte": 1,
#           "gab": 1,
#           "setzen": 1,
#           "genommen": 1,
#           "gekommen": 1,
#           "ausgingen": 1,
#           "schneiden": 1,
#           "griff": 1
#         },
#         "Dimensioning-Size": {
#           "vasto": 2,
#           "alto": 2,
#           "dürre": 2,
#           "langen": 2,
#           "großer": 2,
#           "amplio": 1,
#           "pequeños": 1,
#           "corta": 1,
#           "grandes": 1,
#           "fina": 1,
#           "nueve": 1,
#           "leguas": 1,
#           "honda": 1,
#           "ancha": 1,
#           "Enormes": 1,
#           "estrechos": 1,
#           "inmenso": 1,
#           "enjuto": 1,
#           "abultada": 1,
#           "macizo": 1,
#           "pesado": 1,
#           "menos": 1,
#           "espaciosa": 1,
#           "vastos": 1,
#           "caudaloso": 1,
#           "limitado": 1,
#           "espacioso": 1,
#           "mediana": 1,
#           "fornido": 1,
#           "vigoroso": 1,
#           "espesa": 1,
#           "larga": 1,
#           "enorme": 1,
#           "profunda": 1,
#           "espesos": 1,
#           "ansehnlicher": 1,
#           "unermeßlichen": 1,
#           "großen": 1,
#           "ungeheuren": 1,
#           "niedriger": 1,
#           "untersetzter": 1,
#           "schmalen": 1,
#           "breiten": 1,
#           "breite": 1,
#           "hohe": 1,
#           "weite": 1,
#           "endlosen": 1,
#           "höher": 1,
#           "gebeugte": 1,
#           "knieenden": 1,
#           "große": 1,
#           "stattliche": 1,
#           "von": 1,
#           "guter": 1,
#           "Mittelgröße": 1,
#           "dreibahnig": 1,
#           "dünnen": 1,
#           "ausgebauten": 1,
#           "mittelgroßen": 1,
#           "bequemen": 1,
#           "massigen": 1
#         },
#         "Place-Object": {
#           "Mond": 4,
#           "sol": 3,
#           "peñascos": 2,
#           "Himmel": 2,
#           "boca": 1,
#           "cielo": 1,
#           "orillas": 1,
#           "tierra": 1,
#           "contornos": 1,
#           "muros": 1,
#           "muro": 1,
#           "ventana": 1,
#           "lados": 1,
#           "Sandboden": 1,
#           "Boden": 1,
#           "Erdreich": 1,
#           "Sande": 1,
#           "Dach": 1,
#           "Sonne": 1,
#           "Wolkenschichten": 1,
#           "Sternen": 1,
#           "Erde": 1,
#           "Fensterreihe": 1,
#           "Scheiben": 1,
#           "Rinnstein": 1,
#           "Türschlösser": 1
#         },
#         "Movement-Object": {
#           "ponerse": 2,
#           "corría": 2,
#           "llenado": 1,
#           "bajaba": 1,
#           "descendía": 1,
#           "interrumpían": 1,
#           "crecidos": 1,
#           "inundaban": 1,
#           "fecundaban": 1,
#           "barridos": 1,
#           "cubierto": 1,
#           "surcasen": 1,
#           "desvencijada": 1,
#           "bewässern": 1,
#           "einsanken": 1,
#           "streiften": 1,
#           "rauchenden": 1,
#           "flog": 1,
#           "hinab": 1,
#           "blieb": 1,
#           "stecken": 1,
#           "gezogen": 1,
#           "herumwälzt": 1,
#           "breitet": 1,
#           "ballt": 1,
#           "flattern": 1,
#           "ziehen": 1,
#           "verwebend": 1,
#           "erheben": 1,
#           "schweben": 1,
#           "sammelt": 1,
#           "schweifen": 1,
#           "umhüllt": 1,
#           "dringt": 1,
#           "heran": 1,
#           "zusammenbricht": 1,
#           "gleitet": 1,
#           "vorüber": 1,
#           "Weicht": 1,
#           "rollende": 1,
#           "träufeln": 1,
#           "fiel": 1,
#           "geschwollen": 1,
#           "taumelte": 1,
#           "hievte": 1,
#           "verirrte": 1
#         },
#         "Place-Container-MC": {
#           "Ambato": 2,
#           "Hotel": 2,
#           "árbol": 1,
#           "Río": 1,
#           "Grande": 1,
#           "yerba": 1,
#           "valle": 1,
#           "faldas": 1,
#           "Península": 1,
#           "patria": 1,
#           "puerta": 1,
#           "valles": 1,
#           "Cacabelos": 1,
#           "Waldung": 1,
#           "Land": 1,
#           "Gegend": 1,
#           "Waldblöße": 1,
#           "Wasserspiegel": 1,
#           "Erde": 1,
#           "Gebirgsknoten": 1,
#           "Doppelluppe": 1,
#           "Gebirgsgegend": 1,
#           "Schenkhause": 1,
#           "Thorweg": 1,
#           "Ferne": 1,
#           "Waldweg": 1,
#           "Unterholzes": 1,
#           "Pfad": 1,
#           "Wald": 1,
#           "Sumpf": 1,
#           "Thürschwelle": 1,
#           "Bank": 1,
#           "Thürmen": 1,
#           "Bühne": 1,
#           "Bahnhof": 1,
#           "Taxi": 1,
#           "Taxis": 1,
#           "Stadt": 1,
#           "Unglücksauto": 1,
#           "Wasser": 1,
#           "Schleusenbecken": 1
#         },
#         "Dimensioning-ALT": {
#           "gran": 2,
#           "großes": 2,
#           "larga": 1,
#           "creciente": 1,
#           "inmenso": 1,
#           "grandes": 1,
#           "pesadas": 1,
#           "nahe": 1,
#           "nahen": 1,
#           "weit": 1,
#           "kurz": 1,
#           "tiefer": 1,
#           "kräftiger": 1,
#           "klein": 1,
#           "lange": 1,
#           "tief": 1,
#           "höheren": 1
#         },
#         "Dimensioning-Distance": {
#           "a": 3,
#           "cerca": 1,
#           "pocos": 1,
#           "pasos": 1,
#           "espesa": 1,
#           "Dispersos": 1,
#           "remotas": 1,
#           "tiro": 1,
#           "de": 1,
#           "ballesta": 1,
#           "muy": 1,
#           "corta": 1,
#           "distancia": 1,
#           "poco": 1,
#           "distante": 1,
#           "meilenweit": 1,
#           "tiefe": 1,
#           "Weiterhin": 1,
#           "fußtiefen": 1,
#           "tief": 1,
#           "tiefen": 1,
#           "hochgelegene": 1,
#           "fernen": 1,
#           "unfern": 1,
#           "fern": 1,
#           "soweit": 1,
#           "das": 1,
#           "Auge": 1,
#           "reicht": 1,
#           "nächsten": 1,
#           "nahe": 1,
#           "vom": 1,
#           "Bahnhof": 1,
#           "fünfzig": 1,
#           "Zwei": 1,
#           "zweihundert": 1,
#           "Kilometern": 1,
#           "von": 1
#         },
#         "Movement-Light": {
#           "esparcía": 2,
#           "sah": 2,
#           "auf": 2,
#           "veía": 1,
#           "iluminaba": 1,
#           "atezado": 1,
#           "fosforecían": 1,
#           "Vióseles": 1,
#           "ver": 1,
#           "volvieron": 1,
#           "contemplar": 1,
#           "descubría": 1,
#           "Registrando": 1,
#           "Miren": 1,
#           "mirar": 1,
#           "visto": 1,
#           "divisaban": 1,
#           "mirado": 1,
#           "notar": 1,
#           "brillaba": 1,
#           "contemplarse": 1,
#           "interponía": 1,
#           "desaparecía": 1,
#           "vagaba": 1,
#           "veíase": 1,
#           "divisado": 1,
#           "inundaba": 1,
#           "confundiendo": 1,
#           "vistos": 1,
#           "übersehen": 1,
#           "ansah": 1,
#           "blinken": 1,
#           "fallen": 1,
#           "erleuchtet": 1,
#           "erglühte": 1,
#           "blitzendem": 1,
#           "überströmte": 1,
#           "erquicken": 1,
#           "angaffte": 1,
#           "stechen": 1,
#           "heraufwinkte": 1,
#           "um": 1,
#           "fällt": 1,
#           "besprengt": 1,
#           "schimmernden": 1,
#           "zündet": 1,
#           "läuft": 1,
#           "herab": 1,
#           "brennender": 1,
#           "leuchten": 1,
#           "erleuchten": 1,
#           "wirf": 1,
#           "hinaus": 1,
#           "umherflackert": 1,
#           "sieht": 1,
#           "hinüber": 1,
#           "mattscheinend": 1,
#           "leuchtenden": 1,
#           "schimmern": 1,
#           "erleuchtete": 1,
#           "glänzt": 1,
#           "hineinzuwerfen": 1,
#           "blickt": 1,
#           "ausschaue": 1,
#           "entdecke": 1,
#           "auszublicken": 1,
#           "nahm": 1,
#           "traf": 1,
#           "fotografierte": 1
#         },
#         "Movement-Sound": {
#           "sagte": 5,
#           "dijo": 2,
#           "hablar": 2,
#           "contestó": 1,
#           "murmuró": 1,
#           "replicó": 1,
#           "exclamó": 1,
#           "calla": 1,
#           "oírlo": 1,
#           "traerá": 1,
#           "murmurando": 1,
#           "rugían": 1,
#           "hurras": 1,
#           "Llevaban": 1,
#           "hablaban": 1,
#           "elogiándolos": 1,
#           "reía": 1,
#           "levante": 1,
#           "comunicarse": 1,
#           "turbaba": 1,
#           "produciendo": 1,
#           "rauschende": 1,
#           "behandelte": 1,
#           "fragenden": 1,
#           "anredete": 1,
#           "wispert": 1,
#           "tönt": 1,
#           "murmelte": 1,
#           "rief": 1,
#           "zu": 1,
#           "erwähnen": 1,
#           "Hören": 1,
#           "sagen": 1,
#           "nennt": 1,
#           "hörte": 1,
#           "höre": 1,
#           "gefragt": 1,
#           "vor": 1,
#           "brechen": 1,
#           "lachen": 1,
#           "erkundigt": 1
#         },
#         "Direction": {
#           "nach": 9,
#           "de": 7,
#           "in": 7,
#           "aus": 7,
#           "auf": 7,
#           "a": 6,
#           "über": 6,
#           "von": 5,
#           "an": 5,
#           "zum": 5,
#           "al": 4,
#           "por": 4,
#           "hacia": 3,
#           "bis": 3,
#           "vom": 3,
#           "desde": 2,
#           "del": 2,
#           "hasta": 2,
#           "Durch": 2,
#           "zu": 2,
#           "durch": 2,
#           "um": 2,
#           "her": 2,
#           "unter": 2,
#           "rauf": 2,
#           "runter": 2,
#           "ans": 2,
#           "en": 1,
#           "través": 1,
#           "derecha": 1,
#           "izquierda": 1,
#           "norte": 1,
#           "gegen": 1,
#           "herab": 1,
#           "schräger": 1,
#           "Direction": 1,
#           "hinterwärts": 1,
#           "vor": 1,
#           "Weg": 1,
#           "neben": 1,
#           "seitlich": 1,
#           "ins": 1,
#           "danach": 1,
#           "übern": 1,
#           "hin": 1
#         },
#         "Direction-ALT": {
#           "a": 7,
#           "de": 2,
#           "über": 2,
#           "in": 2,
#           "aus": 2,
#           "al": 1,
#           "hacia": 1,
#           "del": 1,
#           "desde": 1,
#           "hasta": 1,
#           "zur": 1,
#           "zu": 1,
#           "Zu": 1,
#           "ans": 1,
#           "von": 1,
#           "auf": 1,
#           "nach": 1,
#           "ins": 1
#         },
#         "Place-Object-MC": {
#           "Fenster": 3,
#           "rostro": 1,
#           "ventanilla": 1,
#           "techumbre": 1,
#           "pavimento": 1,
#           "Boden": 1,
#           "Seite": 1,
#           "Horizont": 1,
#           "Hausthür": 1,
#           "Mond": 1,
#           "Tür": 1
#         },
#         "Place-Abstract": {
#           "Fuße": 2,
#           "lado": 1,
#           "centro": 1,
#           "círculo": 1,
#           "extremos": 1,
#           "Grenzen": 1,
#           "Bogen": 1,
#           "Gipfel": 1,
#           "Spitze": 1
#         },
#         "Place-Abstract-MC": {},
#         "Place-ALT": {
#           "mundo": 3,
#           "Bembibre": 2,
#           "Koblenz": 2,
#           "Geschäft": 2,
#           "seno": 1,
#           "edén": 1,
#           "casa": 1,
#           "contornos": 1,
#           "sombra": 1,
#           "Oede": 1,
#           "Sonne": 1,
#           "Mainz": 1,
#           "Wege": 1,
#           "Post": 1,
#           "Stück": 1
#         },
#         "Movement-Smell": {
#           "wohlriechend": 1,
#           "roch": 1
#         },
#         "Positioning-ALT": {
#           "en": 5,
#           "bajo": 1,
#           "jener": 1,
#           "in": 1,
#           "vor": 1,
#           "hinter": 1
#         }
#       }
#     }
#   }
# }

# %%
# safe annotation statistics to files in root of dh2025 repo

for result_type in results:
    filename: str = f'annotation_statistics__{result_type}.json'
    json_file_str: str = json.dumps(results[result_type], indent=2, sort_keys=False, ensure_ascii=False)

    if (os.path.isfile(filename)):
        print(f'JSON file {filename} already exists and will be overwritten.')

    with open(filename, 'w') as file:
        file.write(json_file_str)
        print(f'JSON file {filename} successfully created.')
# Out:
# JSON file annotation_statistics__whole_chapters.json already exists and will be overwritten.
# JSON file annotation_statistics__whole_chapters.json successfully created.
# JSON file annotation_statistics__first_1000_token.json already exists and will be overwritten.
# JSON file annotation_statistics__first_1000_token.json successfully created.

# %% [markdown]
# ### 2 - get bar charts with annotation amounts of all chapters normalized to their token amount

# %%
# for annotation data with all tokens
# you may manipulate and save the plotly diagram as png image file by using the interface of the html output

data_dict: dict = {
    'text': list(itertools.chain(*[[item] * 21 for item in [
        'DEU19_030', 
        'DEU19_001', 
        'DEU20_002', 
        'DEU20_021', 
        'SPA19_001', 
        'SPA19_008', 
        'LAT19_004', 
        'LAT19_041'
    ]])),
    'annotation_class': [
        'Place-Container', 
        'Place-Container-MC', 
        'Place-Object', 
        'Place-Object-MC', 
        'Place-Abstract', 
        'Place-Abstract-MC', 
        'Place-ALT',
        'Movement-Subject',
        'Movement-Object',
        'Movement-Light',
        'Movement-Sound',
        'Movement-Smell',
        'Movement-ALT',
        'Dimensioning-Size',
        'Dimensioning-Distance',
        'Dimensioning-Amount',
        'Dimensioning-ALT',
        'Positioning',
        'Positioning-ALT',
        'Direction',
        'Direction-ALT'
    ] * 8,
    'amount': []
}
data_dict['amount'] = list(itertools.chain(*[[results['whole_chapters']['ratios']['cs1'][corpus_file[0]][corpus_file[1]]['annotations_by_class_in_file:total_token_amount_in_file'].get(annotation_class, 0) * 100] for corpus_file in [
    ('canspin-deu-19', 'CANSpiN-deu-19_030_1-1-1.tsv'), 
    ('canspin-deu-19', 'CANSpiN-deu-19_001_1-1-1.tsv'),
    ('canspin-deu-20', 'CANSpiN-deu-20_002_1_shuffled.tsv'),
    ('canspin-deu-20', 'CANSpiN-deu-20_021_1_shuffled.tsv'),
    ('canspin-spa-19', 'CANSpiN-spa-19_001_1.tsv'),
    ('canspin-spa-19', 'CANSpiN-spa-19_008_1.tsv'),
    ('canspin-lat-19', 'CANSpiN-lat-19_004_1.tsv'),
    ('canspin-lat-19', 'CANSpiN-lat-19_041_1.tsv')
] for annotation_class in data_dict['annotation_class'][:21]]))

data: pd.DataFrame = pd.DataFrame(data_dict)

figure: plotly.graph_objects.Figure = plotly.express.bar(
    data_frame=data,
    x='text',
    y='amount',
    color='annotation_class',
    labels={
        "text": "texts",
        "amount": "annotation amount (in %)",
        "annotation_class": "annotation classes"
    },
    title='CS1 annotation amounts inside the initial chapters with all tokens <br><sub>(in percentage of the total token amount of the respective chapter)</sub>',
    color_discrete_map={
        'Place-Container': '#B6D3FF',
        'Place-Container-MC': '#CCDEFF',
        'Place-Object': '#D4EAFF',
        'Place-Object-MC': '#E6F2FF',
        'Place-Abstract': '#89A8F6',
        'Place-Abstract-MC': '#98C3FA',
        'Place-ALT': '#90A6C7',
        'Movement-Subject': '#FF6D6D',
        'Movement-Object': '#F60D00',
        'Movement-Sound': '#FF4949',
        'Movement-Light': '#CA0B0B',
        'Movement-Smell': '#B60000',
        'Movement-ALT': '#960000',
        'Direction': '#92FFBD',
        'Direction-ALT': '#75CC96',
        'Positioning': '#DB8300',
        'Positioning-ALT': '#B56A01',
        'Dimensioning-Distance': '#8AB6AD',
        'Dimensioning-Size': '#7CD3C0',
        'Dimensioning-Amount': '#7EF5D9',
        'Dimensioning-ALT': '#60847B'
    },
    width=1400,
    height=800
)

figure.update_layout(font={'size': 18})

figure.show()

# %%
# for annotation data with 1000 or a maximum of 1000 tokens
# you may manipulate and save the plotly diagram as png image file by using the interface of the html output

data_dict: dict = {
    'text': list(itertools.chain(*[[item] * 21 for item in [
        'DEU19_030', 
        'DEU19_001', 
        'DEU20_002', 
        'DEU20_021', 
        'SPA19_001', 
        'SPA19_008', 
        'LAT19_004', 
        'LAT19_041'
    ]])),
    'annotation_class': [
        'Place-Container', 
        'Place-Container-MC', 
        'Place-Object', 
        'Place-Object-MC', 
        'Place-Abstract', 
        'Place-Abstract-MC', 
        'Place-ALT',
        'Movement-Subject',
        'Movement-Object',
        'Movement-Light',
        'Movement-Sound',
        'Movement-Smell',
        'Movement-ALT',
        'Dimensioning-Size',
        'Dimensioning-Distance',
        'Dimensioning-Amount',
        'Dimensioning-ALT',
        'Positioning',
        'Positioning-ALT',
        'Direction',
        'Direction-ALT'
    ] * 8,
    'amount': []
}
data_dict['amount'] = list(itertools.chain(*[[results['first_1000_token']['ratios']['cs1'][corpus_file[0]][corpus_file[1]]['annotations_by_class_in_file:total_token_amount_in_file'].get(annotation_class, 0) * 100] for corpus_file in [
    ('canspin-deu-19', 'CANSpiN-deu-19_030_1-1-1.tsv'), 
    ('canspin-deu-19', 'CANSpiN-deu-19_001_1-1-1.tsv'),
    ('canspin-deu-20', 'CANSpiN-deu-20_002_1_shuffled.tsv'),
    ('canspin-deu-20', 'CANSpiN-deu-20_021_1_shuffled.tsv'),
    ('canspin-spa-19', 'CANSpiN-spa-19_001_1.tsv'),
    ('canspin-spa-19', 'CANSpiN-spa-19_008_1.tsv'),
    ('canspin-lat-19', 'CANSpiN-lat-19_004_1.tsv'),
    ('canspin-lat-19', 'CANSpiN-lat-19_041_1.tsv')
] for annotation_class in data_dict['annotation_class'][:21]]))

data: pd.DataFrame = pd.DataFrame(data_dict)

figure: plotly.graph_objects.Figure = plotly.express.bar(
    data_frame=data,
    x='text',
    y='amount',
    color='annotation_class',
    labels={
        "text": "texts",
        "amount": "annotation amount (in %)",
        "annotation_class": "annotation classes"
    },
    title=f'CS1 annotation amounts inside the initial chapters with {token_selection[1] - token_selection[0]} tokens <br><sub>(in percentage of the selected token amount of the respective chapter)</sub>',
    color_discrete_map={
        'Place-Container': '#B6D3FF',
        'Place-Container-MC': '#CCDEFF',
        'Place-Object': '#D4EAFF',
        'Place-Object-MC': '#E6F2FF',
        'Place-Abstract': '#89A8F6',
        'Place-Abstract-MC': '#98C3FA',
        'Place-ALT': '#90A6C7',
        'Movement-Subject': '#FF6D6D',
        'Movement-Object': '#F60D00',
        'Movement-Sound': '#FF4949',
        'Movement-Light': '#CA0B0B',
        'Movement-Smell': '#B60000',
        'Movement-ALT': '#960000',
        'Direction': '#92FFBD',
        'Direction-ALT': '#75CC96',
        'Positioning': '#DB8300',
        'Positioning-ALT': '#B56A01',
        'Dimensioning-Distance': '#8AB6AD',
        'Dimensioning-Size': '#7CD3C0',
        'Dimensioning-Amount': '#7EF5D9',
        'Dimensioning-ALT': '#60847B'
    },
    width=1400,
    height=800
)

figure.update_layout(font={'size': 18})

figure.show()
