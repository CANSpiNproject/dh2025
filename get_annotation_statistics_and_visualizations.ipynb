# %%
# imports
from gitma_canspin.canspin import AnnotationAnalyzer

import pandas as pd
import plotly
import json
import os
import itertools

from typing import Tuple

# %%
# load the analyzer with the selected catma project from the catma project folder
analyzer = AnnotationAnalyzer(init_settings={'project_name': 'CATMA_4AA4ADC0-4C28-54F9-B6A1-5DCEFF34B90B_DH2025_CANSpiN'})
# Out:
# gitma_canspin.project - INFO - Loading tagsets ...
# gitma_canspin.project - INFO - 	Found 3 tagset(s).
# gitma_canspin.project - INFO - Loading documents ...
# gitma_canspin.project - INFO - 	Found 6 document(s).
# gitma_canspin.project - INFO - Loading annotation collections ...
# gitma_canspin.project - INFO - 	Found 6 annotation collection(s).
# gitma_canspin.project - INFO - 	Annotation collection "Collection CS1 v1.1.0 - Gold Standard" for document "El pozo del Yocci"
# gitma_canspin.project - INFO - 		Annotations: 201
# gitma_canspin.project - INFO - 	Annotation collection "CS1 v1.1.0 - Nils (Gold: 1)" for document "El Señor de Bembibre"
# gitma_canspin.project - INFO - 		Annotations: 285
# gitma_canspin.project - INFO - 	Annotation collection "CS1 v1.1.0 - Ulrike (Gold standard: 1)" for document "CANSpiN-spa-19-008"
# gitma_canspin.project - INFO - 		Annotations: 1332
# gitma_canspin.project - INFO - 	Annotation collection "Nils -- CS1 1.1.0 (Gold: 1-1-1)" for document "DEU-19_001"
# gitma_canspin.project - INFO - 		Annotations: 898
# gitma_canspin.project - INFO - 	Annotation collection "Nils -- CS1 V.1.1.0 (Gold:1-1-1)" for document "DEU-19_030"
# gitma_canspin.project - INFO - 		Annotations: 1056
# gitma_canspin.project - INFO - 	Annotation collection "Collection CS1 v1.1.0 - Gold Standard" for document "El falso Inca"
# gitma_canspin.project - INFO - 		Annotations: 128
# gitma_canspin.canspin - INFO - The line endings of all texts of the loaded project have been unified to unix standard.

# %%
# display loaded tsv annotations from corpus folders
analyzer.print_tsv_annotations_overview()
# Out:
# gitma_canspin.canspin - INFO - tsv files found in canspin project!
# overview:
# - schema "cs1"
# 	CANSpiN-deu-19_001_1-1-1.tsv
# 	CANSpiN-deu-19_030_1-1-1.tsv
# 	CANSpiN-deu-20_002_1.tsv
# 	CANSpiN-deu-20_021_1.tsv
# 	CANSpiN-lat-19_004_1.tsv
# 	CANSpiN-lat-19_041_1.tsv
# 	CANSpiN-spa-19_001_1.tsv
# 	CANSpiN-spa-19_008_1.tsv

# %%
# get the annotation statistics from the tsv files (for the entire chapters and for the first 1000 tokens respectively)
# and translate the class names into English

# TODO: fix bug in translation of schema totals by class: translation process overwrites results for german texts with the spanish ones,
#       so that the TOTAL by-class-dictionaries refering to the cs1 schema are wrong

token_selection: Tuple[int, int] = (0, 1000)

results: dict = {
    'whole_chapters': analyzer.get_corpus_annotation_statistics(),
    'first_1000_token': analyzer.get_corpus_annotation_statistics({
        'calculations': {
            'amount_of_annotations': True,
            'amount_of_annotations_by_class': True,
            'amount_of_token': True,
            'amount_of_annotated_token': True,
            'amount_of_annotated_token_by_class': True,
            'ratios': True,
            'word_lists_by_class': True
        },
        'custom_grouping': None,
        'text_borders': token_selection
    })
}

def translate_dict(input: dict, translation: dict) -> dict:
    translated: dict = dict([(translation.get(k, k), v) for k, v in input.items()])
    for key, value in translated.items():
        if isinstance(value, dict):
            translated[key] = translate_dict(value, translation)
    return translated

key_translation = {
    'Ort-Container': 'Place-Container',
    'Ort-Container-BK': 'Place-Container-MC',
    'Ort-Objekt': 'Place-Object',
    'Ort-Objekt-BK': 'Place-Object-MC',
    'Ort-Abstrakt': 'Place-Abstract',
    'Ort-Abstrakt-BK': 'Place-Abstract-MC',
    'Ort-ALT': 'Place-ALT',
    'Bewegung-Subjekt': 'Movement-Subject',
    'Bewegung-Objekt': 'Movement-Object',
    'Bewegung-Licht': 'Movement-Light',
    'Bewegung-Schall': 'Movement-Sound',
    'Bewegung-Geruch': 'Movement-Smell',
    'Bewegung-ALT': 'Movement-ALT',
    'Dimensionierung-Groesse': 'Dimensioning-Size',
    'Dimensionierung-Abstand': 'Dimensioning-Distance',
    'Dimensionierung-Menge': 'Dimensioning-Amount',
    'Dimensionierung-ALT': 'Dimensioning-ALT',
    'Positionierung': 'Positioning',
    'Positionierung-ALT': 'Positioning-ALT',
    'Richtung': 'Direction',
    'Richtung-ALT': 'Direction-ALT',
    'Lugar-Contenedor': 'Place-Container',
    'Lugar-Contenedor-CM': 'Place-Container-MC',
    'Lugar-Objeto': 'Place-Object',
    'Lugar-Objeto-CM': 'Place-Object-MC',
    'Lugar-Abstracto': 'Place-Abstract',
    'Lugar-Abstracto-CM': 'Place-Abstract-MC',
    'Lugar-ALT': 'Place-ALT',
    'Movimiento-Sujeto': 'Movement-Subject',
    'Movimiento-Objeto': 'Movement-Object',
    'Movimiento-Luz': 'Movement-Light',
    'Movimiento-Sonido': 'Movement-Sound',
    'Movimiento-Olfato': 'Movement-Smell',
    'Movimiento-ALT': 'Movement-ALT',
    'Dimensionamiento-Tamaño': 'Dimensioning-Size',
    'Dimensionamiento-Distancia': 'Dimensioning-Distance',
    'Dimensionamiento-Cantitad': 'Dimensioning-Amount',
    'Dimensionamiento-ALT': 'Dimensioning-ALT',
    'Posicionamiento': 'Positioning',
    'Posicionamiento-ALT': 'Positioning-ALT',
    'Dirección': 'Direction',
    'Dirección-ALT': 'Direction-ALT'
}

for result_type in results:
    results[result_type] = translate_dict(input=results[result_type], translation=key_translation)

# %%
# print annotation statistics

for result_type in results:
    print(
        json.dumps(
            results[result_type],
            indent=2, 
            sort_keys=False, 
            ensure_ascii=False
        )
    )
# Out:
# {
#   "amount_of_annotations": {
#     "cs1": {
#       "canspin-spa-19": {
#         "CANSpiN-spa-19_001_1.tsv": 269,
#         "CANSpiN-spa-19_008_1.tsv": 728,
#         "TOTAL": 997
#       },
#       "canspin-lat-19": {
#         "CANSpiN-lat-19_004_1.tsv": 128,
#         "CANSpiN-lat-19_041_1.tsv": 199,
#         "TOTAL": 327
#       },
#       "canspin-deu-20": {
#         "CANSpiN-deu-20_002_1.tsv": 412,
#         "CANSpiN-deu-20_021_1.tsv": 154,
#         "TOTAL": 566
#       },
#       "canspin-deu-19": {
#         "CANSpiN-deu-19_001_1-1-1.tsv": 898,
#         "CANSpiN-deu-19_030_1-1-1.tsv": 1056,
#         "TOTAL": 1954
#       },
#       "TOTAL": 3844
#     }
#   },
#   "amount_of_annotations_by_class": {
#     "cs1": {
#       "canspin-spa-19": {
#         "CANSpiN-spa-19_001_1.tsv": {
#           "Movement-ALT": 72,
#           "Movement-Subject": 37,
#           "Direction": 35,
#           "Place-Container": 24,
#           "Movement-Sound": 20,
#           "Positioning": 15,
#           "Direction-ALT": 12,
#           "Place-Container-MC": 11,
#           "Dimensioning-Amount": 7,
#           "Place-ALT": 6,
#           "Dimensioning-Size": 6,
#           "Movement-Object": 6,
#           "Movement-Light": 5,
#           "Place-Object": 5,
#           "Dimensioning-ALT": 3,
#           "Positioning-ALT": 3,
#           "Dimensioning-Distance": 2,
#           "Place-Object-MC": 0,
#           "Place-Abstract": 0,
#           "Place-Abstract-MC": 0,
#           "Movement-Smell": 0
#         },
#         "CANSpiN-spa-19_008_1.tsv": {
#           "Positioning": 126,
#           "Place-Container": 114,
#           "Movement-ALT": 90,
#           "Movement-Subject": 72,
#           "Direction": 55,
#           "Dimensioning-Size": 45,
#           "Movement-Light": 38,
#           "Movement-Sound": 38,
#           "Dimensioning-Amount": 35,
#           "Place-Object": 32,
#           "Place-Object-MC": 14,
#           "Movement-Object": 11,
#           "Direction-ALT": 11,
#           "Place-ALT": 10,
#           "Positioning-ALT": 9,
#           "Dimensioning-Distance": 7,
#           "Place-Abstract": 7,
#           "Place-Container-MC": 7,
#           "Dimensioning-ALT": 5,
#           "Place-Abstract-MC": 1,
#           "Movement-Smell": 1
#         },
#         "TOTAL": {
#           "Movement-ALT": 162,
#           "Movement-Subject": 109,
#           "Direction": 90,
#           "Place-Container": 138,
#           "Movement-Sound": 58,
#           "Positioning": 141,
#           "Direction-ALT": 23,
#           "Place-Container-MC": 18,
#           "Dimensioning-Amount": 42,
#           "Place-ALT": 16,
#           "Dimensioning-Size": 51,
#           "Movement-Object": 17,
#           "Movement-Light": 43,
#           "Place-Object": 37,
#           "Dimensioning-ALT": 8,
#           "Positioning-ALT": 12,
#           "Dimensioning-Distance": 9,
#           "Place-Object-MC": 14,
#           "Place-Abstract": 7,
#           "Place-Abstract-MC": 1,
#           "Movement-Smell": 1
#         }
#       },
#       "canspin-lat-19": {
#         "CANSpiN-lat-19_004_1.tsv": {
#           "Movement-ALT": 20,
#           "Movement-Subject": 19,
#           "Place-Container": 16,
#           "Positioning": 16,
#           "Dimensioning-Amount": 10,
#           "Movement-Object": 9,
#           "Movement-Sound": 8,
#           "Place-Container-MC": 7,
#           "Dimensioning-Size": 6,
#           "Direction": 5,
#           "Movement-Light": 4,
#           "Dimensioning-Distance": 3,
#           "Dimensioning-ALT": 2,
#           "Place-Object": 1,
#           "Direction-ALT": 1,
#           "Place-Object-MC": 1,
#           "Place-Abstract": 0,
#           "Place-Abstract-MC": 0,
#           "Place-ALT": 0,
#           "Movement-Smell": 0,
#           "Positioning-ALT": 0
#         },
#         "CANSpiN-lat-19_041_1.tsv": {
#           "Place-Container": 60,
#           "Positioning": 33,
#           "Movement-Subject": 29,
#           "Movement-ALT": 17,
#           "Direction": 12,
#           "Dimensioning-Amount": 10,
#           "Dimensioning-Size": 8,
#           "Place-Object": 6,
#           "Movement-Light": 4,
#           "Place-Container-MC": 4,
#           "Movement-Sound": 4,
#           "Place-ALT": 3,
#           "Positioning-ALT": 2,
#           "Dimensioning-Distance": 2,
#           "Movement-Object": 2,
#           "Dimensioning-ALT": 1,
#           "Direction-ALT": 1,
#           "Place-Abstract": 1,
#           "Place-Object-MC": 0,
#           "Place-Abstract-MC": 0,
#           "Movement-Smell": 0
#         },
#         "TOTAL": {
#           "Movement-ALT": 37,
#           "Movement-Subject": 48,
#           "Place-Container": 76,
#           "Positioning": 49,
#           "Dimensioning-Amount": 20,
#           "Movement-Object": 11,
#           "Movement-Sound": 12,
#           "Place-Container-MC": 11,
#           "Dimensioning-Size": 14,
#           "Direction": 17,
#           "Movement-Light": 8,
#           "Dimensioning-Distance": 5,
#           "Dimensioning-ALT": 3,
#           "Place-Object": 7,
#           "Direction-ALT": 2,
#           "Place-Object-MC": 1,
#           "Place-Abstract": 1,
#           "Place-Abstract-MC": 0,
#           "Place-ALT": 3,
#           "Movement-Smell": 0,
#           "Positioning-ALT": 2
#         }
#       },
#       "canspin-deu-20": {
#         "CANSpiN-deu-20_002_1.tsv": {
#           "Movement-Subject": 75,
#           "Movement-ALT": 66,
#           "Direction": 54,
#           "Place-Container": 50,
#           "Movement-Sound": 44,
#           "Positioning": 42,
#           "Place-Container-MC": 17,
#           "Place-ALT": 15,
#           "Direction-ALT": 13,
#           "Positioning-ALT": 7,
#           "Dimensioning-ALT": 6,
#           "Movement-Light": 5,
#           "Dimensioning-Amount": 4,
#           "Movement-Smell": 3,
#           "Movement-Object": 3,
#           "Place-Object-MC": 2,
#           "Place-Object": 2,
#           "Dimensioning-Distance": 1,
#           "Place-Abstract-MC": 1,
#           "Dimensioning-Size": 1,
#           "Place-Abstract": 1
#         },
#         "CANSpiN-deu-20_021_1.tsv": {
#           "Place-Container": 37,
#           "Movement-Subject": 28,
#           "Positioning": 22,
#           "Movement-ALT": 19,
#           "Direction": 16,
#           "Dimensioning-Size": 5,
#           "Direction-ALT": 4,
#           "Movement-Light": 4,
#           "Place-Container-MC": 4,
#           "Movement-Object": 3,
#           "Place-ALT": 2,
#           "Dimensioning-ALT": 2,
#           "Dimensioning-Amount": 2,
#           "Place-Object": 2,
#           "Place-Object-MC": 2,
#           "Dimensioning-Distance": 1,
#           "Movement-Sound": 1,
#           "Place-Abstract": 0,
#           "Place-Abstract-MC": 0,
#           "Movement-Smell": 0,
#           "Positioning-ALT": 0
#         },
#         "TOTAL": {
#           "Movement-Subject": 103,
#           "Movement-ALT": 85,
#           "Direction": 70,
#           "Place-Container": 87,
#           "Movement-Sound": 45,
#           "Positioning": 64,
#           "Place-Container-MC": 21,
#           "Place-ALT": 17,
#           "Direction-ALT": 17,
#           "Positioning-ALT": 7,
#           "Dimensioning-ALT": 8,
#           "Movement-Light": 9,
#           "Dimensioning-Amount": 6,
#           "Movement-Smell": 3,
#           "Movement-Object": 6,
#           "Place-Object-MC": 4,
#           "Place-Object": 4,
#           "Dimensioning-Distance": 2,
#           "Place-Abstract-MC": 1,
#           "Dimensioning-Size": 6,
#           "Place-Abstract": 1
#         }
#       },
#       "canspin-deu-19": {
#         "CANSpiN-deu-19_001_1-1-1.tsv": {
#           "Place-Container": 131,
#           "Movement-Subject": 126,
#           "Positioning": 120,
#           "Movement-ALT": 105,
#           "Direction": 95,
#           "Movement-Sound": 92,
#           "Dimensioning-Amount": 52,
#           "Movement-Light": 35,
#           "Dimensioning-Size": 33,
#           "Place-Container-MC": 32,
#           "Dimensioning-Distance": 15,
#           "Place-Object": 10,
#           "Place-Abstract": 10,
#           "Dimensioning-ALT": 10,
#           "Movement-Object": 9,
#           "Direction-ALT": 7,
#           "Place-Object-MC": 6,
#           "Place-ALT": 5,
#           "Positioning-ALT": 4,
#           "Place-Abstract-MC": 1,
#           "Movement-Smell": 0
#         },
#         "CANSpiN-deu-19_030_1-1-1.tsv": {
#           "Movement-ALT": 187,
#           "Positioning": 133,
#           "Movement-Subject": 122,
#           "Movement-Sound": 102,
#           "Place-Container": 91,
#           "Direction": 86,
#           "Movement-Light": 51,
#           "Dimensioning-Amount": 44,
#           "Direction-ALT": 37,
#           "Place-ALT": 37,
#           "Dimensioning-Size": 36,
#           "Dimensioning-ALT": 28,
#           "Place-Object": 25,
#           "Movement-Object": 23,
#           "Place-Container-MC": 20,
#           "Positioning-ALT": 12,
#           "Place-Object-MC": 8,
#           "Dimensioning-Distance": 7,
#           "Place-Abstract": 5,
#           "Place-Abstract-MC": 2,
#           "Movement-Smell": 0
#         },
#         "TOTAL": {
#           "Place-Container": 222,
#           "Movement-Subject": 248,
#           "Positioning": 253,
#           "Movement-ALT": 292,
#           "Direction": 181,
#           "Movement-Sound": 194,
#           "Dimensioning-Amount": 96,
#           "Movement-Light": 86,
#           "Dimensioning-Size": 69,
#           "Place-Container-MC": 52,
#           "Dimensioning-Distance": 22,
#           "Place-Object": 35,
#           "Place-Abstract": 15,
#           "Dimensioning-ALT": 38,
#           "Movement-Object": 32,
#           "Direction-ALT": 44,
#           "Place-Object-MC": 14,
#           "Place-ALT": 42,
#           "Positioning-ALT": 16,
#           "Place-Abstract-MC": 3,
#           "Movement-Smell": 0
#         }
#       },
#       "TOTAL": {
#         "Movement-ALT": 377,
#         "Movement-Subject": 351,
#         "Direction": 251,
#         "Place-Container": 309,
#         "Movement-Sound": 239,
#         "Positioning": 317,
#         "Direction-ALT": 61,
#         "Place-Container-MC": 73,
#         "Dimensioning-Amount": 102,
#         "Place-ALT": 59,
#         "Dimensioning-Size": 75,
#         "Movement-Object": 38,
#         "Movement-Light": 95,
#         "Place-Object": 39,
#         "Dimensioning-ALT": 46,
#         "Positioning-ALT": 23,
#         "Dimensioning-Distance": 24,
#         "Place-Object-MC": 18,
#         "Place-Abstract": 16,
#         "Place-Abstract-MC": 4,
#         "Movement-Smell": 3
#       }
#     }
#   },
#   "amount_of_token": {
#     "cs1": {
#       "canspin-spa-19": {
#         "CANSpiN-spa-19_001_1.tsv": 1843,
#         "CANSpiN-spa-19_008_1.tsv": 4300,
#         "TOTAL": 6143
#       },
#       "canspin-lat-19": {
#         "CANSpiN-lat-19_004_1.tsv": 1210,
#         "CANSpiN-lat-19_041_1.tsv": 1074,
#         "TOTAL": 2284
#       },
#       "canspin-deu-20": {
#         "CANSpiN-deu-20_002_1.tsv": 2689,
#         "CANSpiN-deu-20_021_1.tsv": 744,
#         "TOTAL": 3433
#       },
#       "canspin-deu-19": {
#         "CANSpiN-deu-19_001_1-1-1.tsv": 5491,
#         "CANSpiN-deu-19_030_1-1-1.tsv": 7179,
#         "TOTAL": 12670
#       },
#       "TOTAL": 24530
#     }
#   },
#   "amount_of_annotated_token": {
#     "cs1": {
#       "canspin-spa-19": {
#         "CANSpiN-spa-19_001_1.tsv": 277,
#         "CANSpiN-spa-19_008_1.tsv": 775,
#         "TOTAL": 1052
#       },
#       "canspin-lat-19": {
#         "CANSpiN-lat-19_004_1.tsv": 135,
#         "CANSpiN-lat-19_041_1.tsv": 205,
#         "TOTAL": 340
#       },
#       "canspin-deu-20": {
#         "CANSpiN-deu-20_002_1.tsv": 446,
#         "CANSpiN-deu-20_021_1.tsv": 161,
#         "TOTAL": 607
#       },
#       "canspin-deu-19": {
#         "CANSpiN-deu-19_001_1-1-1.tsv": 942,
#         "CANSpiN-deu-19_030_1-1-1.tsv": 1132,
#         "TOTAL": 2074
#       },
#       "TOTAL": 4073
#     }
#   },
#   "amount_of_annotated_token_by_class": {
#     "cs1": {
#       "canspin-spa-19": {
#         "CANSpiN-spa-19_001_1.tsv": {
#           "Movement-ALT": 72,
#           "Movement-Subject": 38,
#           "Direction": 35,
#           "Place-Container": 26,
#           "Movement-Sound": 20,
#           "Positioning": 15,
#           "Direction-ALT": 12,
#           "Place-Container-MC": 11,
#           "Dimensioning-Distance": 7,
#           "Dimensioning-Amount": 7,
#           "Dimensioning-Size": 6,
#           "Place-ALT": 6,
#           "Movement-Object": 6,
#           "Place-Object": 5,
#           "Movement-Light": 5,
#           "Dimensioning-ALT": 3,
#           "Positioning-ALT": 3,
#           "Place-Object-MC": 0,
#           "Place-Abstract": 0,
#           "Place-Abstract-MC": 0,
#           "Movement-Smell": 0
#         },
#         "CANSpiN-spa-19_008_1.tsv": {
#           "Positioning": 142,
#           "Place-Container": 117,
#           "Movement-ALT": 90,
#           "Movement-Subject": 72,
#           "Dimensioning-Size": 61,
#           "Direction": 58,
#           "Movement-Light": 39,
#           "Movement-Sound": 38,
#           "Dimensioning-Amount": 35,
#           "Place-Object": 32,
#           "Place-Object-MC": 14,
#           "Dimensioning-Distance": 13,
#           "Movement-Object": 12,
#           "Direction-ALT": 11,
#           "Place-ALT": 10,
#           "Positioning-ALT": 10,
#           "Place-Abstract": 7,
#           "Place-Container-MC": 7,
#           "Dimensioning-ALT": 5,
#           "Place-Abstract-MC": 1,
#           "Movement-Smell": 1
#         },
#         "TOTAL": {
#           "Movement-ALT": 162,
#           "Movement-Subject": 110,
#           "Direction": 93,
#           "Place-Container": 143,
#           "Movement-Sound": 58,
#           "Positioning": 157,
#           "Direction-ALT": 23,
#           "Place-Container-MC": 18,
#           "Dimensioning-Distance": 20,
#           "Dimensioning-Amount": 42,
#           "Dimensioning-Size": 67,
#           "Place-ALT": 16,
#           "Movement-Object": 18,
#           "Place-Object": 37,
#           "Movement-Light": 44,
#           "Dimensioning-ALT": 8,
#           "Positioning-ALT": 13,
#           "Place-Object-MC": 14,
#           "Place-Abstract": 7,
#           "Place-Abstract-MC": 1,
#           "Movement-Smell": 1
#         }
#       },
#       "canspin-lat-19": {
#         "CANSpiN-lat-19_004_1.tsv": {
#           "Movement-ALT": 20,
#           "Movement-Subject": 19,
#           "Place-Container": 18,
#           "Positioning": 16,
#           "Dimensioning-Amount": 12,
#           "Movement-Object": 9,
#           "Movement-Sound": 8,
#           "Place-Container-MC": 8,
#           "Dimensioning-Size": 6,
#           "Direction": 5,
#           "Dimensioning-Distance": 5,
#           "Movement-Light": 4,
#           "Dimensioning-ALT": 2,
#           "Place-Object": 1,
#           "Direction-ALT": 1,
#           "Place-Object-MC": 1,
#           "Place-Abstract": 0,
#           "Place-Abstract-MC": 0,
#           "Place-ALT": 0,
#           "Movement-Smell": 0,
#           "Positioning-ALT": 0
#         },
#         "CANSpiN-lat-19_041_1.tsv": {
#           "Place-Container": 64,
#           "Positioning": 33,
#           "Movement-Subject": 29,
#           "Movement-ALT": 17,
#           "Direction": 13,
#           "Dimensioning-Amount": 10,
#           "Dimensioning-Size": 9,
#           "Place-Object": 6,
#           "Movement-Light": 4,
#           "Place-Container-MC": 4,
#           "Movement-Sound": 4,
#           "Place-ALT": 3,
#           "Positioning-ALT": 2,
#           "Dimensioning-Distance": 2,
#           "Movement-Object": 2,
#           "Dimensioning-ALT": 1,
#           "Direction-ALT": 1,
#           "Place-Abstract": 1,
#           "Place-Object-MC": 0,
#           "Place-Abstract-MC": 0,
#           "Movement-Smell": 0
#         },
#         "TOTAL": {
#           "Movement-ALT": 37,
#           "Movement-Subject": 48,
#           "Place-Container": 82,
#           "Positioning": 49,
#           "Dimensioning-Amount": 22,
#           "Movement-Object": 11,
#           "Movement-Sound": 12,
#           "Place-Container-MC": 12,
#           "Dimensioning-Size": 15,
#           "Direction": 18,
#           "Dimensioning-Distance": 7,
#           "Movement-Light": 8,
#           "Dimensioning-ALT": 3,
#           "Place-Object": 7,
#           "Direction-ALT": 2,
#           "Place-Object-MC": 1,
#           "Place-Abstract": 1,
#           "Place-Abstract-MC": 0,
#           "Place-ALT": 3,
#           "Movement-Smell": 0,
#           "Positioning-ALT": 2
#         }
#       },
#       "canspin-deu-20": {
#         "CANSpiN-deu-20_002_1.tsv": {
#           "Movement-Subject": 86,
#           "Movement-ALT": 73,
#           "Direction": 54,
#           "Place-Container": 52,
#           "Movement-Sound": 47,
#           "Positioning": 42,
#           "Place-Container-MC": 17,
#           "Place-ALT": 15,
#           "Direction-ALT": 13,
#           "Dimensioning-Distance": 12,
#           "Positioning-ALT": 7,
#           "Dimensioning-ALT": 6,
#           "Movement-Light": 5,
#           "Dimensioning-Amount": 4,
#           "Movement-Smell": 3,
#           "Movement-Object": 3,
#           "Place-Object": 2,
#           "Place-Object-MC": 2,
#           "Place-Abstract-MC": 1,
#           "Dimensioning-Size": 1,
#           "Place-Abstract": 1
#         },
#         "CANSpiN-deu-20_021_1.tsv": {
#           "Place-Container": 37,
#           "Movement-Subject": 29,
#           "Positioning": 22,
#           "Movement-ALT": 21,
#           "Direction": 16,
#           "Dimensioning-Size": 6,
#           "Movement-Light": 5,
#           "Direction-ALT": 4,
#           "Place-Container-MC": 4,
#           "Dimensioning-Distance": 3,
#           "Movement-Object": 3,
#           "Dimensioning-ALT": 2,
#           "Dimensioning-Amount": 2,
#           "Place-ALT": 2,
#           "Place-Object": 2,
#           "Place-Object-MC": 2,
#           "Movement-Sound": 1,
#           "Place-Abstract": 0,
#           "Place-Abstract-MC": 0,
#           "Movement-Smell": 0,
#           "Positioning-ALT": 0
#         },
#         "TOTAL": {
#           "Movement-Subject": 115,
#           "Movement-ALT": 94,
#           "Direction": 70,
#           "Place-Container": 89,
#           "Movement-Sound": 48,
#           "Positioning": 64,
#           "Place-Container-MC": 21,
#           "Place-ALT": 17,
#           "Direction-ALT": 17,
#           "Dimensioning-Distance": 15,
#           "Positioning-ALT": 7,
#           "Dimensioning-ALT": 8,
#           "Movement-Light": 10,
#           "Dimensioning-Amount": 6,
#           "Movement-Smell": 3,
#           "Movement-Object": 6,
#           "Place-Object": 4,
#           "Place-Object-MC": 4,
#           "Place-Abstract-MC": 1,
#           "Dimensioning-Size": 7,
#           "Place-Abstract": 1
#         }
#       },
#       "canspin-deu-19": {
#         "CANSpiN-deu-19_001_1-1-1.tsv": {
#           "Movement-Subject": 136,
#           "Place-Container": 131,
#           "Positioning": 120,
#           "Movement-ALT": 110,
#           "Movement-Sound": 100,
#           "Direction": 97,
#           "Dimensioning-Amount": 62,
#           "Movement-Light": 41,
#           "Dimensioning-Size": 34,
#           "Place-Container-MC": 32,
#           "Dimensioning-Distance": 16,
#           "Place-Object": 10,
#           "Place-Abstract": 10,
#           "Movement-Object": 10,
#           "Dimensioning-ALT": 10,
#           "Direction-ALT": 7,
#           "Place-Object-MC": 6,
#           "Place-ALT": 5,
#           "Positioning-ALT": 4,
#           "Place-Abstract-MC": 1,
#           "Movement-Smell": 0
#         },
#         "CANSpiN-deu-19_030_1-1-1.tsv": {
#           "Movement-ALT": 197,
#           "Movement-Subject": 138,
#           "Positioning": 137,
#           "Movement-Sound": 115,
#           "Place-Container": 91,
#           "Direction": 86,
#           "Movement-Light": 58,
#           "Dimensioning-Amount": 57,
#           "Dimensioning-Size": 38,
#           "Place-ALT": 37,
#           "Direction-ALT": 37,
#           "Dimensioning-ALT": 28,
#           "Movement-Object": 27,
#           "Place-Object": 25,
#           "Place-Container-MC": 20,
#           "Dimensioning-Distance": 14,
#           "Positioning-ALT": 12,
#           "Place-Object-MC": 8,
#           "Place-Abstract": 5,
#           "Place-Abstract-MC": 2,
#           "Movement-Smell": 0
#         },
#         "TOTAL": {
#           "Movement-Subject": 274,
#           "Place-Container": 222,
#           "Positioning": 257,
#           "Movement-ALT": 307,
#           "Movement-Sound": 215,
#           "Direction": 183,
#           "Dimensioning-Amount": 119,
#           "Movement-Light": 99,
#           "Dimensioning-Size": 72,
#           "Place-Container-MC": 52,
#           "Dimensioning-Distance": 30,
#           "Place-Object": 35,
#           "Place-Abstract": 15,
#           "Movement-Object": 37,
#           "Dimensioning-ALT": 38,
#           "Direction-ALT": 44,
#           "Place-Object-MC": 14,
#           "Place-ALT": 42,
#           "Positioning-ALT": 16,
#           "Place-Abstract-MC": 3,
#           "Movement-Smell": 0
#         }
#       },
#       "TOTAL": {
#         "Movement-ALT": 401,
#         "Movement-Subject": 389,
#         "Direction": 253,
#         "Place-Container": 311,
#         "Movement-Sound": 263,
#         "Positioning": 321,
#         "Direction-ALT": 61,
#         "Place-Container-MC": 73,
#         "Dimensioning-Distance": 45,
#         "Dimensioning-Amount": 125,
#         "Dimensioning-Size": 79,
#         "Place-ALT": 59,
#         "Movement-Object": 43,
#         "Place-Object": 39,
#         "Movement-Light": 109,
#         "Dimensioning-ALT": 46,
#         "Positioning-ALT": 23,
#         "Place-Object-MC": 18,
#         "Place-Abstract": 16,
#         "Place-Abstract-MC": 4,
#         "Movement-Smell": 3
#       }
#     }
#   },
#   "ratios": {
#     "cs1": {
#       "canspin-spa-19": {
#         "CANSpiN-spa-19_001_1.tsv": {
#           "token_of_file:total_token_amount_in_corpus": 0.3,
#           "annotated_token_by_class_in_file:annotated_token_by_class_in_corpus": {
#             "Movement-ALT": 0.4444,
#             "Movement-Subject": 0.3454,
#             "Direction": 0.3763,
#             "Place-Container": 0.1818,
#             "Movement-Sound": 0.3448,
#             "Positioning": 0.0955,
#             "Direction-ALT": 0.5217,
#             "Place-Container-MC": 0.6111,
#             "Dimensioning-Distance": 0.35,
#             "Dimensioning-Amount": 0.1666,
#             "Dimensioning-Size": 0.0895,
#             "Place-ALT": 0.375,
#             "Movement-Object": 0.3333,
#             "Place-Object": 0.1351,
#             "Movement-Light": 0.1136,
#             "Dimensioning-ALT": 0.375,
#             "Positioning-ALT": 0.2307,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.2633
#           },
#           "annotated_token_by_class_in_file:total_token_amount_in_file": {
#             "Movement-ALT": 0.039,
#             "Movement-Subject": 0.0206,
#             "Direction": 0.0189,
#             "Place-Container": 0.0141,
#             "Movement-Sound": 0.0108,
#             "Positioning": 0.0081,
#             "Direction-ALT": 0.0065,
#             "Place-Container-MC": 0.0059,
#             "Dimensioning-Distance": 0.0037,
#             "Dimensioning-Amount": 0.0037,
#             "Dimensioning-Size": 0.0032,
#             "Place-ALT": 0.0032,
#             "Movement-Object": 0.0032,
#             "Place-Object": 0.0027,
#             "Movement-Light": 0.0027,
#             "Dimensioning-ALT": 0.0016,
#             "Positioning-ALT": 0.0016,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.1502
#           },
#           "annotated_token_by_class_in_file:total_annotated_token_amount_in_file": {
#             "Movement-ALT": 0.2599,
#             "Movement-Subject": 0.1371,
#             "Direction": 0.1263,
#             "Place-Container": 0.0938,
#             "Movement-Sound": 0.0722,
#             "Positioning": 0.0541,
#             "Direction-ALT": 0.0433,
#             "Place-Container-MC": 0.0397,
#             "Dimensioning-Distance": 0.0252,
#             "Dimensioning-Amount": 0.0252,
#             "Dimensioning-Size": 0.0216,
#             "Place-ALT": 0.0216,
#             "Movement-Object": 0.0216,
#             "Place-Object": 0.018,
#             "Movement-Light": 0.018,
#             "Dimensioning-ALT": 0.0108,
#             "Positioning-ALT": 0.0108,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Movement-Smell": 0.0
#           },
#           "annotations_by_class_in_file:annotations_by_class_in_corpus": {
#             "Movement-ALT": 0.4444,
#             "Movement-Subject": 0.3394,
#             "Direction": 0.3888,
#             "Place-Container": 0.1739,
#             "Movement-Sound": 0.3448,
#             "Positioning": 0.1063,
#             "Direction-ALT": 0.5217,
#             "Place-Container-MC": 0.6111,
#             "Dimensioning-Amount": 0.1666,
#             "Place-ALT": 0.375,
#             "Dimensioning-Size": 0.1176,
#             "Movement-Object": 0.3529,
#             "Movement-Light": 0.1162,
#             "Place-Object": 0.1351,
#             "Dimensioning-ALT": 0.375,
#             "Positioning-ALT": 0.25,
#             "Dimensioning-Distance": 0.2222,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.2698
#           },
#           "annotations_by_class_in_file:total_token_amount_in_file": {
#             "Movement-ALT": 0.039,
#             "Movement-Subject": 0.02,
#             "Direction": 0.0189,
#             "Place-Container": 0.013,
#             "Movement-Sound": 0.0108,
#             "Positioning": 0.0081,
#             "Direction-ALT": 0.0065,
#             "Place-Container-MC": 0.0059,
#             "Dimensioning-Amount": 0.0037,
#             "Place-ALT": 0.0032,
#             "Dimensioning-Size": 0.0032,
#             "Movement-Object": 0.0032,
#             "Movement-Light": 0.0027,
#             "Place-Object": 0.0027,
#             "Dimensioning-ALT": 0.0016,
#             "Positioning-ALT": 0.0016,
#             "Dimensioning-Distance": 0.001,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.1459
#           },
#           "annotations_by_class_in_file:total_annotations_amount_in_file": {
#             "Movement-ALT": 0.2676,
#             "Movement-Subject": 0.1375,
#             "Direction": 0.1301,
#             "Place-Container": 0.0892,
#             "Movement-Sound": 0.0743,
#             "Positioning": 0.0557,
#             "Direction-ALT": 0.0446,
#             "Place-Container-MC": 0.0408,
#             "Dimensioning-Amount": 0.026,
#             "Place-ALT": 0.0223,
#             "Dimensioning-Size": 0.0223,
#             "Movement-Object": 0.0223,
#             "Movement-Light": 0.0185,
#             "Place-Object": 0.0185,
#             "Dimensioning-ALT": 0.0111,
#             "Positioning-ALT": 0.0111,
#             "Dimensioning-Distance": 0.0074,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Movement-Smell": 0.0
#           }
#         },
#         "CANSpiN-spa-19_008_1.tsv": {
#           "token_of_file:total_token_amount_in_corpus": 0.6999,
#           "annotated_token_by_class_in_file:annotated_token_by_class_in_corpus": {
#             "Movement-ALT": 0.5555,
#             "Movement-Subject": 0.6545,
#             "Direction": 0.6236,
#             "Place-Container": 0.8181,
#             "Movement-Sound": 0.6551,
#             "Positioning": 0.9044,
#             "Direction-ALT": 0.4782,
#             "Place-Container-MC": 0.3888,
#             "Dimensioning-Distance": 0.65,
#             "Dimensioning-Amount": 0.8333,
#             "Dimensioning-Size": 0.9104,
#             "Place-ALT": 0.625,
#             "Movement-Object": 0.6666,
#             "Place-Object": 0.8648,
#             "Movement-Light": 0.8863,
#             "Dimensioning-ALT": 0.625,
#             "Positioning-ALT": 0.7692,
#             "Place-Object-MC": 1.0,
#             "Place-Abstract": 1.0,
#             "Place-Abstract-MC": 1.0,
#             "Movement-Smell": 1.0,
#             "TOTAL": 0.7366
#           },
#           "annotated_token_by_class_in_file:total_token_amount_in_file": {
#             "Positioning": 0.033,
#             "Place-Container": 0.0272,
#             "Movement-ALT": 0.0209,
#             "Movement-Subject": 0.0167,
#             "Dimensioning-Size": 0.0141,
#             "Direction": 0.0134,
#             "Movement-Light": 0.009,
#             "Movement-Sound": 0.0088,
#             "Dimensioning-Amount": 0.0081,
#             "Place-Object": 0.0074,
#             "Place-Object-MC": 0.0032,
#             "Dimensioning-Distance": 0.003,
#             "Movement-Object": 0.0027,
#             "Direction-ALT": 0.0025,
#             "Place-ALT": 0.0023,
#             "Positioning-ALT": 0.0023,
#             "Place-Abstract": 0.0016,
#             "Place-Container-MC": 0.0016,
#             "Dimensioning-ALT": 0.0011,
#             "Place-Abstract-MC": 0.0002,
#             "Movement-Smell": 0.0002,
#             "TOTAL": 0.1802
#           },
#           "annotated_token_by_class_in_file:total_annotated_token_amount_in_file": {
#             "Positioning": 0.1832,
#             "Place-Container": 0.1509,
#             "Movement-ALT": 0.1161,
#             "Movement-Subject": 0.0929,
#             "Dimensioning-Size": 0.0787,
#             "Direction": 0.0748,
#             "Movement-Light": 0.0503,
#             "Movement-Sound": 0.049,
#             "Dimensioning-Amount": 0.0451,
#             "Place-Object": 0.0412,
#             "Place-Object-MC": 0.018,
#             "Dimensioning-Distance": 0.0167,
#             "Movement-Object": 0.0154,
#             "Direction-ALT": 0.0141,
#             "Place-ALT": 0.0129,
#             "Positioning-ALT": 0.0129,
#             "Place-Abstract": 0.009,
#             "Place-Container-MC": 0.009,
#             "Dimensioning-ALT": 0.0064,
#             "Place-Abstract-MC": 0.0012,
#             "Movement-Smell": 0.0012
#           },
#           "annotations_by_class_in_file:annotations_by_class_in_corpus": {
#             "Movement-ALT": 0.5555,
#             "Movement-Subject": 0.6605,
#             "Direction": 0.6111,
#             "Place-Container": 0.826,
#             "Movement-Sound": 0.6551,
#             "Positioning": 0.8936,
#             "Direction-ALT": 0.4782,
#             "Place-Container-MC": 0.3888,
#             "Dimensioning-Amount": 0.8333,
#             "Place-ALT": 0.625,
#             "Dimensioning-Size": 0.8823,
#             "Movement-Object": 0.647,
#             "Movement-Light": 0.8837,
#             "Place-Object": 0.8648,
#             "Dimensioning-ALT": 0.625,
#             "Positioning-ALT": 0.75,
#             "Dimensioning-Distance": 0.7777,
#             "Place-Object-MC": 1.0,
#             "Place-Abstract": 1.0,
#             "Place-Abstract-MC": 1.0,
#             "Movement-Smell": 1.0,
#             "TOTAL": 0.7301
#           },
#           "annotations_by_class_in_file:total_token_amount_in_file": {
#             "Positioning": 0.0293,
#             "Place-Container": 0.0265,
#             "Movement-ALT": 0.0209,
#             "Movement-Subject": 0.0167,
#             "Direction": 0.0127,
#             "Dimensioning-Size": 0.0104,
#             "Movement-Light": 0.0088,
#             "Movement-Sound": 0.0088,
#             "Dimensioning-Amount": 0.0081,
#             "Place-Object": 0.0074,
#             "Place-Object-MC": 0.0032,
#             "Movement-Object": 0.0025,
#             "Direction-ALT": 0.0025,
#             "Place-ALT": 0.0023,
#             "Positioning-ALT": 0.002,
#             "Dimensioning-Distance": 0.0016,
#             "Place-Abstract": 0.0016,
#             "Place-Container-MC": 0.0016,
#             "Dimensioning-ALT": 0.0011,
#             "Place-Abstract-MC": 0.0002,
#             "Movement-Smell": 0.0002,
#             "TOTAL": 0.1693
#           },
#           "annotations_by_class_in_file:total_annotations_amount_in_file": {
#             "Positioning": 0.173,
#             "Place-Container": 0.1565,
#             "Movement-ALT": 0.1236,
#             "Movement-Subject": 0.0989,
#             "Direction": 0.0755,
#             "Dimensioning-Size": 0.0618,
#             "Movement-Light": 0.0521,
#             "Movement-Sound": 0.0521,
#             "Dimensioning-Amount": 0.048,
#             "Place-Object": 0.0439,
#             "Place-Object-MC": 0.0192,
#             "Movement-Object": 0.0151,
#             "Direction-ALT": 0.0151,
#             "Place-ALT": 0.0137,
#             "Positioning-ALT": 0.0123,
#             "Dimensioning-Distance": 0.0096,
#             "Place-Abstract": 0.0096,
#             "Place-Container-MC": 0.0096,
#             "Dimensioning-ALT": 0.0068,
#             "Place-Abstract-MC": 0.0013,
#             "Movement-Smell": 0.0013
#           }
#         },
#         "TOTAL": {
#           "token_of_corpus:total_token_amount_in_schema": 0.2504,
#           "annotated_token_by_class_in_corpus:annotated_token_by_class_in_schema": {
#             "Movement-ALT": 0.814,
#             "Movement-Subject": 0.6962,
#             "Direction": 0.8378,
#             "Place-Container": 0.6355,
#             "Movement-Sound": 0.8285,
#             "Positioning": 0.7621,
#             "Direction-ALT": 0.92,
#             "Place-Container-MC": 0.6,
#             "Dimensioning-Distance": 0.7407,
#             "Dimensioning-Amount": 0.6562,
#             "Dimensioning-Size": 0.817,
#             "Place-ALT": 0.8421,
#             "Movement-Object": 0.6206,
#             "Place-Object": 0.8409,
#             "Movement-Light": 0.8461,
#             "Dimensioning-ALT": 0.7272,
#             "Positioning-ALT": 0.8666,
#             "Place-Object-MC": 0.9333,
#             "Place-Abstract": 0.875,
#             "Place-Abstract-MC": 1.0,
#             "Movement-Smell": 1.0,
#             "TOTAL": 0.2582
#           },
#           "annotated_token_by_class_in_corpus:total_token_amount_in_corpus": {
#             "Movement-ALT": 0.0263,
#             "Movement-Subject": 0.0179,
#             "Direction": 0.0151,
#             "Place-Container": 0.0232,
#             "Movement-Sound": 0.0094,
#             "Positioning": 0.0255,
#             "Direction-ALT": 0.0037,
#             "Place-Container-MC": 0.0029,
#             "Dimensioning-Distance": 0.0032,
#             "Dimensioning-Amount": 0.0068,
#             "Dimensioning-Size": 0.0109,
#             "Place-ALT": 0.0026,
#             "Movement-Object": 0.0029,
#             "Place-Object": 0.006,
#             "Movement-Light": 0.0071,
#             "Dimensioning-ALT": 0.0013,
#             "Positioning-ALT": 0.0021,
#             "Place-Object-MC": 0.0022,
#             "Place-Abstract": 0.0011,
#             "Place-Abstract-MC": 0.0001,
#             "Movement-Smell": 0.0001,
#             "TOTAL": 0.1712
#           },
#           "annotated_token_by_class_in_corpus:total_annotated_token_amount_in_corpus": {
#             "Movement-ALT": 0.1539,
#             "Movement-Subject": 0.1045,
#             "Direction": 0.0884,
#             "Place-Container": 0.1359,
#             "Movement-Sound": 0.0551,
#             "Positioning": 0.1492,
#             "Direction-ALT": 0.0218,
#             "Place-Container-MC": 0.0171,
#             "Dimensioning-Distance": 0.019,
#             "Dimensioning-Amount": 0.0399,
#             "Dimensioning-Size": 0.0636,
#             "Place-ALT": 0.0152,
#             "Movement-Object": 0.0171,
#             "Place-Object": 0.0351,
#             "Movement-Light": 0.0418,
#             "Dimensioning-ALT": 0.0076,
#             "Positioning-ALT": 0.0123,
#             "Place-Object-MC": 0.0133,
#             "Place-Abstract": 0.0066,
#             "Place-Abstract-MC": 0.0009,
#             "Movement-Smell": 0.0009
#           },
#           "annotations_by_class_in_corpus:annotations_by_class_in_schema": {
#             "Movement-ALT": 0.814,
#             "Movement-Subject": 0.6942,
#             "Direction": 0.8411,
#             "Place-Container": 0.6448,
#             "Movement-Sound": 0.8285,
#             "Positioning": 0.7421,
#             "Direction-ALT": 0.92,
#             "Place-Container-MC": 0.6206,
#             "Dimensioning-Amount": 0.6774,
#             "Place-ALT": 0.8421,
#             "Dimensioning-Size": 0.7846,
#             "Movement-Object": 0.6071,
#             "Movement-Light": 0.8431,
#             "Place-Object": 0.8409,
#             "Dimensioning-ALT": 0.7272,
#             "Positioning-ALT": 0.8571,
#             "Dimensioning-Distance": 0.6428,
#             "Place-Object-MC": 0.9333,
#             "Place-Abstract": 0.875,
#             "Place-Abstract-MC": 1.0,
#             "Movement-Smell": 1.0,
#             "TOTAL": 0.2593
#           },
#           "annotations_by_class_in_corpus:total_token_amount_in_corpus": {
#             "Movement-ALT": 0.0263,
#             "Movement-Subject": 0.0177,
#             "Direction": 0.0146,
#             "Place-Container": 0.0224,
#             "Movement-Sound": 0.0094,
#             "Positioning": 0.0229,
#             "Direction-ALT": 0.0037,
#             "Place-Container-MC": 0.0029,
#             "Dimensioning-Amount": 0.0068,
#             "Place-ALT": 0.0026,
#             "Dimensioning-Size": 0.0083,
#             "Movement-Object": 0.0027,
#             "Movement-Light": 0.0069,
#             "Place-Object": 0.006,
#             "Dimensioning-ALT": 0.0013,
#             "Positioning-ALT": 0.0019,
#             "Dimensioning-Distance": 0.0014,
#             "Place-Object-MC": 0.0022,
#             "Place-Abstract": 0.0011,
#             "Place-Abstract-MC": 0.0001,
#             "Movement-Smell": 0.0001,
#             "TOTAL": 0.1622
#           },
#           "annotations_by_class_in_corpus:total_annotations_amount_in_corpus": {
#             "Movement-ALT": 0.1624,
#             "Movement-Subject": 0.1093,
#             "Direction": 0.0902,
#             "Place-Container": 0.1384,
#             "Movement-Sound": 0.0581,
#             "Positioning": 0.1414,
#             "Direction-ALT": 0.023,
#             "Place-Container-MC": 0.018,
#             "Dimensioning-Amount": 0.0421,
#             "Place-ALT": 0.016,
#             "Dimensioning-Size": 0.0511,
#             "Movement-Object": 0.017,
#             "Movement-Light": 0.0431,
#             "Place-Object": 0.0371,
#             "Dimensioning-ALT": 0.008,
#             "Positioning-ALT": 0.012,
#             "Dimensioning-Distance": 0.009,
#             "Place-Object-MC": 0.014,
#             "Place-Abstract": 0.007,
#             "Place-Abstract-MC": 0.001,
#             "Movement-Smell": 0.001
#           }
#         }
#       },
#       "canspin-lat-19": {
#         "CANSpiN-lat-19_004_1.tsv": {
#           "token_of_file:total_token_amount_in_corpus": 0.5297,
#           "annotated_token_by_class_in_file:annotated_token_by_class_in_corpus": {
#             "Movement-ALT": 0.5405,
#             "Movement-Subject": 0.3958,
#             "Place-Container": 0.2195,
#             "Positioning": 0.3265,
#             "Dimensioning-Amount": 0.5454,
#             "Movement-Object": 0.8181,
#             "Movement-Sound": 0.6666,
#             "Place-Container-MC": 0.6666,
#             "Dimensioning-Size": 0.4,
#             "Direction": 0.2777,
#             "Dimensioning-Distance": 0.7142,
#             "Movement-Light": 0.5,
#             "Dimensioning-ALT": 0.6666,
#             "Place-Object": 0.1428,
#             "Direction-ALT": 0.5,
#             "Place-Object-MC": 1.0,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0,
#             "TOTAL": 0.397
#           },
#           "annotated_token_by_class_in_file:total_token_amount_in_file": {
#             "Movement-ALT": 0.0165,
#             "Movement-Subject": 0.0157,
#             "Place-Container": 0.0148,
#             "Positioning": 0.0132,
#             "Dimensioning-Amount": 0.0099,
#             "Movement-Object": 0.0074,
#             "Movement-Sound": 0.0066,
#             "Place-Container-MC": 0.0066,
#             "Dimensioning-Size": 0.0049,
#             "Direction": 0.0041,
#             "Dimensioning-Distance": 0.0041,
#             "Movement-Light": 0.0033,
#             "Dimensioning-ALT": 0.0016,
#             "Place-Object": 0.0008,
#             "Direction-ALT": 0.0008,
#             "Place-Object-MC": 0.0008,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0,
#             "TOTAL": 0.1115
#           },
#           "annotated_token_by_class_in_file:total_annotated_token_amount_in_file": {
#             "Movement-ALT": 0.1481,
#             "Movement-Subject": 0.1407,
#             "Place-Container": 0.1333,
#             "Positioning": 0.1185,
#             "Dimensioning-Amount": 0.0888,
#             "Movement-Object": 0.0666,
#             "Movement-Sound": 0.0592,
#             "Place-Container-MC": 0.0592,
#             "Dimensioning-Size": 0.0444,
#             "Direction": 0.037,
#             "Dimensioning-Distance": 0.037,
#             "Movement-Light": 0.0296,
#             "Dimensioning-ALT": 0.0148,
#             "Place-Object": 0.0074,
#             "Direction-ALT": 0.0074,
#             "Place-Object-MC": 0.0074,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0
#           },
#           "annotations_by_class_in_file:annotations_by_class_in_corpus": {
#             "Movement-ALT": 0.5405,
#             "Movement-Subject": 0.3958,
#             "Place-Container": 0.2105,
#             "Positioning": 0.3265,
#             "Dimensioning-Amount": 0.5,
#             "Movement-Object": 0.8181,
#             "Movement-Sound": 0.6666,
#             "Place-Container-MC": 0.6363,
#             "Dimensioning-Size": 0.4285,
#             "Direction": 0.2941,
#             "Movement-Light": 0.5,
#             "Dimensioning-Distance": 0.6,
#             "Dimensioning-ALT": 0.6666,
#             "Place-Object": 0.1428,
#             "Direction-ALT": 0.5,
#             "Place-Object-MC": 1.0,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0,
#             "TOTAL": 0.3914
#           },
#           "annotations_by_class_in_file:total_token_amount_in_file": {
#             "Movement-ALT": 0.0165,
#             "Movement-Subject": 0.0157,
#             "Place-Container": 0.0132,
#             "Positioning": 0.0132,
#             "Dimensioning-Amount": 0.0082,
#             "Movement-Object": 0.0074,
#             "Movement-Sound": 0.0066,
#             "Place-Container-MC": 0.0057,
#             "Dimensioning-Size": 0.0049,
#             "Direction": 0.0041,
#             "Movement-Light": 0.0033,
#             "Dimensioning-Distance": 0.0024,
#             "Dimensioning-ALT": 0.0016,
#             "Place-Object": 0.0008,
#             "Direction-ALT": 0.0008,
#             "Place-Object-MC": 0.0008,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0,
#             "TOTAL": 0.1057
#           },
#           "annotations_by_class_in_file:total_annotations_amount_in_file": {
#             "Movement-ALT": 0.1562,
#             "Movement-Subject": 0.1484,
#             "Place-Container": 0.125,
#             "Positioning": 0.125,
#             "Dimensioning-Amount": 0.0781,
#             "Movement-Object": 0.0703,
#             "Movement-Sound": 0.0625,
#             "Place-Container-MC": 0.0546,
#             "Dimensioning-Size": 0.0468,
#             "Direction": 0.039,
#             "Movement-Light": 0.0312,
#             "Dimensioning-Distance": 0.0234,
#             "Dimensioning-ALT": 0.0156,
#             "Place-Object": 0.0078,
#             "Direction-ALT": 0.0078,
#             "Place-Object-MC": 0.0078,
#             "Place-Abstract": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 0.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 0.0
#           }
#         },
#         "CANSpiN-lat-19_041_1.tsv": {
#           "token_of_file:total_token_amount_in_corpus": 0.4702,
#           "annotated_token_by_class_in_file:annotated_token_by_class_in_corpus": {
#             "Movement-ALT": 0.4594,
#             "Movement-Subject": 0.6041,
#             "Place-Container": 0.7804,
#             "Positioning": 0.6734,
#             "Dimensioning-Amount": 0.4545,
#             "Movement-Object": 0.1818,
#             "Movement-Sound": 0.3333,
#             "Place-Container-MC": 0.3333,
#             "Dimensioning-Size": 0.6,
#             "Direction": 0.7222,
#             "Dimensioning-Distance": 0.2857,
#             "Movement-Light": 0.5,
#             "Dimensioning-ALT": 0.3333,
#             "Place-Object": 0.8571,
#             "Direction-ALT": 0.5,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract": 1.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 1.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 1.0,
#             "TOTAL": 0.6029
#           },
#           "annotated_token_by_class_in_file:total_token_amount_in_file": {
#             "Place-Container": 0.0595,
#             "Positioning": 0.0307,
#             "Movement-Subject": 0.027,
#             "Movement-ALT": 0.0158,
#             "Direction": 0.0121,
#             "Dimensioning-Amount": 0.0093,
#             "Dimensioning-Size": 0.0083,
#             "Place-Object": 0.0055,
#             "Movement-Light": 0.0037,
#             "Place-Container-MC": 0.0037,
#             "Movement-Sound": 0.0037,
#             "Place-ALT": 0.0027,
#             "Positioning-ALT": 0.0018,
#             "Dimensioning-Distance": 0.0018,
#             "Movement-Object": 0.0018,
#             "Dimensioning-ALT": 0.0009,
#             "Direction-ALT": 0.0009,
#             "Place-Abstract": 0.0009,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.1908
#           },
#           "annotated_token_by_class_in_file:total_annotated_token_amount_in_file": {
#             "Place-Container": 0.3121,
#             "Positioning": 0.1609,
#             "Movement-Subject": 0.1414,
#             "Movement-ALT": 0.0829,
#             "Direction": 0.0634,
#             "Dimensioning-Amount": 0.0487,
#             "Dimensioning-Size": 0.0439,
#             "Place-Object": 0.0292,
#             "Movement-Light": 0.0195,
#             "Place-Container-MC": 0.0195,
#             "Movement-Sound": 0.0195,
#             "Place-ALT": 0.0146,
#             "Positioning-ALT": 0.0097,
#             "Dimensioning-Distance": 0.0097,
#             "Movement-Object": 0.0097,
#             "Dimensioning-ALT": 0.0048,
#             "Direction-ALT": 0.0048,
#             "Place-Abstract": 0.0048,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Movement-Smell": 0.0
#           },
#           "annotations_by_class_in_file:annotations_by_class_in_corpus": {
#             "Movement-ALT": 0.4594,
#             "Movement-Subject": 0.6041,
#             "Place-Container": 0.7894,
#             "Positioning": 0.6734,
#             "Dimensioning-Amount": 0.5,
#             "Movement-Object": 0.1818,
#             "Movement-Sound": 0.3333,
#             "Place-Container-MC": 0.3636,
#             "Dimensioning-Size": 0.5714,
#             "Direction": 0.7058,
#             "Movement-Light": 0.5,
#             "Dimensioning-Distance": 0.4,
#             "Dimensioning-ALT": 0.3333,
#             "Place-Object": 0.8571,
#             "Direction-ALT": 0.5,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract": 1.0,
#             "Place-Abstract-MC": 0.0,
#             "Place-ALT": 1.0,
#             "Movement-Smell": 0.0,
#             "Positioning-ALT": 1.0,
#             "TOTAL": 0.6085
#           },
#           "annotations_by_class_in_file:total_token_amount_in_file": {
#             "Place-Container": 0.0558,
#             "Positioning": 0.0307,
#             "Movement-Subject": 0.027,
#             "Movement-ALT": 0.0158,
#             "Direction": 0.0111,
#             "Dimensioning-Amount": 0.0093,
#             "Dimensioning-Size": 0.0074,
#             "Place-Object": 0.0055,
#             "Movement-Light": 0.0037,
#             "Place-Container-MC": 0.0037,
#             "Movement-Sound": 0.0037,
#             "Place-ALT": 0.0027,
#             "Positioning-ALT": 0.0018,
#             "Dimensioning-Distance": 0.0018,
#             "Movement-Object": 0.0018,
#             "Dimensioning-ALT": 0.0009,
#             "Direction-ALT": 0.0009,
#             "Place-Abstract": 0.0009,
#             "Place-Object-MC": 0.0,
#             "Place-Abstract-MC": 0.0,
#             "Movement-Smell": 0.0,
#             "TOTAL": 0.1852
#           },
#           "annotations_by_class_in_file:total_annotations_amount_in_file": {
#             "Place-Container": 0.3015,
#             "Positioning": 0.1658,
# ...
#             "tiefer": 1,
#             "großes": 1,
#             "kräftiger": 1
#           },
#           "Place-Abstract-MC": {},
#           "Movement-Smell": {}
#         }
#       },
#       "TOTAL": {
#         "Movement-Subject": {
#           "ging": 5,
#           "gehen": 2,
#           "kaufen": 2,
#           "kaufte": 2,
#           "verkaufen": 2,
#           "fuhr": 2,
#           "schleppte": 2,
#           "abstellen": 1,
#           "nehmen": 1,
#           "aufnehmen": 1,
#           "ankam": 1,
#           "abgeben": 1,
#           "heranwinken": 1,
#           "abgefahren": 1,
#           "angekommen": 1,
#           "winkte": 1,
#           "heran": 1,
#           "suchte": 1,
#           "bezahlen": 1,
#           "gesucht": 1,
#           "stürze": 1,
#           "hinunterrenne": 1,
#           "abgeworfen": 1,
#           "bringt": 1,
#           "einlaufen": 1,
#           "schickten": 1,
#           "stürzt": 1,
#           "betrete": 1,
#           "gestoßen": 1,
#           "herum": 1,
#           "gegangen": 1,
#           "verkaufte": 1,
#           "verteilte": 1,
#           "wandte": 1,
#           "bog": 1,
#           "legte": 1,
#           "hockte": 1,
#           "kauerte": 1,
#           "kniete": 1,
#           "verlassen": 1,
#           "wies": 1,
#           "verschenken": 1,
#           "rieb": 1,
#           "ein": 1,
#           "wischte": 1,
#           "putzte": 1,
#           "vorfuhr": 1,
#           "aufsuchte": 1,
#           "führte": 1,
#           "gewaschen": 1,
#           "hängte": 1,
#           "angesiedelt": 1,
#           "haust": 1,
#           "ausgespannt": 1,
#           "gingen": 1,
#           "gespannt": 1,
#           "galoppiren": 1,
#           "angebrachten": 1,
#           "hielt": 1,
#           "fest": 1,
#           "durchschnitten": 1,
#           "erreichte": 1,
#           "anhielt": 1,
#           "zeigte": 1,
#           "lenkte": 1,
#           "entgegen": 1,
#           "abstieg": 1,
#           "reichte": 1,
#           "geleitete": 1,
#           "nachtragend": 1,
#           "bekränzt": 1,
#           "locken": 1,
#           "rastet": 1,
#           "gestützt": 1,
#           "wandelt": 1,
#           "durchschritten": 1,
#           "hüllen": 1,
#           "aufsteht": 1
#         },
#         "Direction": {
#           "auf": 10,
#           "in": 9,
#           "nach": 8,
#           "aus": 7,
#           "an": 5,
#           "über": 5,
#           "vom": 4,
#           "von": 4,
#           "runter": 3,
#           "rauf": 3,
#           "zum": 3,
#           "bis": 3,
#           "ans": 2,
#           "her": 2,
#           "Durch": 2,
#           "zu": 2,
#           "durch": 2,
#           "um": 2,
#           "seitlich": 1,
#           "übern": 1,
#           "ins": 1,
#           "hin": 1,
#           "danach": 1,
#           "gegen": 1,
#           "herab": 1,
#           "schräger": 1,
#           "Direction": 1,
#           "unter": 1,
#           "hinterwärts": 1
#         },
#         "Place-Container-MC": {
#           "Bühne": 3,
#           "Zeitungsstand": 1,
#           "Bonn": 1,
#           "Taxi": 1,
#           "Taxis": 1,
#           "Hotel": 1,
#           "Zimmer": 1,
#           "Schleusenbecken": 1,
#           "Unglücksauto": 1,
#           "Stadt": 1,
#           "Wasser": 1,
#           "Waldung": 1,
#           "Land": 1,
#           "Gegend": 1,
#           "Waldblöße": 1,
#           "Wasserspiegel": 1,
#           "Erde": 1,
#           "Gebirgsknoten": 1,
#           "Doppelluppe": 1,
#           "Gebirgsgegend": 1,
#           "Schenkhause": 1,
#           "Thorweg": 1,
#           "Ferne": 1,
#           "Waldweg": 1,
#           "Unterholzes": 1,
#           "Pfad": 1,
#           "Wald": 1,
#           "Sumpf": 1,
#           "Thürschwelle": 1,
#           "Bank": 1,
#           "Thürmen": 1
#         },
#         "Dimensioning-Amount": {
#           "beiden": 5,
#           "zwei": 3,
#           "drei": 2,
#           "eine": 2,
#           "Menge": 2,
#           "vielen": 2,
#           "meisten": 1,
#           "sechs": 1,
#           "viel": 1,
#           "fünftausend": 1,
#           "einige": 1,
#           "ganze": 1,
#           "mehrere": 1,
#           "zahllose": 1,
#           "hundert": 1,
#           "ganzes": 1,
#           "stellenweise": 1,
#           "ein": 1,
#           "paar": 1,
#           "Massen": 1,
#           "der": 1,
#           "jeder": 1
#         },
#         "Dimensioning-ALT": {
#           "lange": 2,
#           "nahe": 2,
#           "großes": 2,
#           "lang": 1,
#           "höheren": 1,
#           "nahen": 1,
#           "weit": 1,
#           "kurz": 1,
#           "tiefer": 1,
#           "kräftiger": 1
#         },
#         "Movement-ALT": {
#           "aus": 3,
#           "haben": 3,
#           "verlassen": 2,
#           "machte": 2,
#           "zeigten": 2,
#           "hielt": 2,
#           "kam": 2,
#           "durchschneiden": 2,
#           "ablaufen": 1,
#           "geraten": 1,
#           "heißen": 1,
#           "bringen": 1,
#           "heißt": 1,
#           "durchgehe": 1,
#           "annehmen": 1,
#           "gemacht": 1,
#           "bediene": 1,
#           "übergelaufen": 1,
#           "erscheint": 1,
#           "steigerte": 1,
#           "kommt": 1,
#           "steigt": 1,
#           "ab": 1,
#           "führe": 1,
#           "verfalle": 1,
#           "unterlaufen": 1,
#           "steigert": 1,
#           "nannten": 1,
#           "schlagen": 1,
#           "hört": 1,
#           "riß": 1,
#           "zurückfiel": 1,
#           "vorkamen": 1,
#           "machen": 1,
#           "hatte": 1,
#           "legen": 1,
#           "gelang": 1,
#           "gekommen": 1,
#           "setzen": 1,
#           "brachte": 1,
#           "ausgingen": 1,
#           "gab": 1,
#           "genommen": 1,
#           "griff": 1,
#           "getrennt": 1,
#           "bedankte": 1,
#           "schneiden": 1,
#           "bemerken": 1,
#           "finden": 1,
#           "unterbricht": 1,
#           "bergen": 1,
#           "winden": 1,
#           "versteckten": 1,
#           "verliert": 1,
#           "verwandelt": 1,
#           "zurückgezogen": 1,
#           "zerlöcherte": 1,
#           "besetzte": 1,
#           "zerknickte": 1,
#           "bedeckte": 1,
#           "zerbrochen": 1,
#           "steckenden": 1,
#           "verlieren": 1,
#           "gehaltene": 1,
#           "führte": 1,
#           "durchschnittenen": 1,
#           "beschrieb": 1,
#           "hält": 1,
#           "schien": 1,
#           "Fragend": 1,
#           "bekommen": 1,
#           "verlorene": 1,
#           "führt": 1,
#           "geht": 1,
#           "gerufen": 1,
#           "herabgekommen": 1,
#           "gegrüßt": 1,
#           "ziehen": 1,
#           "erhebt": 1,
#           "wäscht": 1,
#           "verschwinden": 1,
#           "verbirgt": 1,
#           "schwebendem": 1,
#           "Zug": 1
#         },
#         "Place-Container": {
#           "Haide": 8,
#           "Wagen": 7,
#           "Stadt": 6,
#           "Bahnhof": 4,
#           "Hotel": 3,
#           "Zimmer": 3,
#           "Teiche": 3,
#           "Häuser": 3,
#           "Bahnsteigtreppe": 2,
#           "Zug": 2,
#           "Hotels": 2,
#           "Sportwagen": 2,
#           "Fuhrwerk": 2,
#           "Schuppen": 2,
#           "Erde": 2,
#           "Bahnhofs": 1,
#           " ": 1,
#           "Bahnhofstreppen": 1,
#           "treppen": 1,
#           "Kiosken": 1,
#           "Treppe": 1,
#           "Portierloge": 1,
#           "Badewanne": 1,
#           "Schule": 1,
#           "Bad": 1,
#           "Landstadt": 1,
#           "Holsteins": 1,
#           "Bude": 1,
#           "Stadtkino": 1,
#           "Straßenausbesserungen": 1,
#           "Ponton": 1,
#           "Kran": 1,
#           "Umkreis": 1,
#           "Schlitten": 1,
#           "Hof": 1,
#           "Kinos": 1,
#           "Ding": 1,
#           "Schaufenster": 1,
#           "Marktplatz": 1,
#           "Karren": 1,
#           "Maschine": 1,
#           "Umgehungsstraße": 1,
#           "Hofloch": 1,
#           "Westberlin": 1,
#           "Straße": 1,
#           "Platz": 1,
#           "Schmutz": 1,
#           "Lieferwagen": 1,
#           "Ladenstraßen": 1,
#           "Fahrbahn": 1,
#           "Morgenlicht": 1,
#           "Theil": 1,
#           "Wälder": 1,
#           "Lausitzen": 1,
#           "Niederlausitz": 1,
#           "Kieferwaldungen": 1,
#           "Dunkel": 1,
#           "Städte": 1,
#           "Dörfer": 1,
#           "Vorwerke": 1,
#           "Höhenzug": 1,
#           "Dickicht": 1,
#           "Hügel": 1,
#           "Oberlausitz": 1,
#           "Thäler": 1,
#           "Waldung": 1,
#           "Flüsse": 1,
#           "Haideflächen": 1,
#           "Nähe": 1,
#           "Görlitz": 1,
#           "Flüßchen": 1,
#           "Moorbruch": 1,
#           "Mark": 1,
#           "Kanäle": 1,
#           "Spreewaldes": 1,
#           "Kelle": 1,
#           "Innern": 1,
#           "Bäche": 1,
#           "Wagens": 1,
#           "Stiege": 1,
#           "Sandwege": 1,
#           "Priebus": 1,
#           "Landstraße": 1,
#           "Haidehügels": 1,
#           "Gräben": 1,
#           "Fuhrwerks": 1,
#           "Wiesengrunde": 1,
#           "Schenkhaus": 1,
#           "Stallung": 1,
#           "Scheuer": 1,
#           "Wiesen": 1,
#           "Torfgräberhütte": 1,
#           "Königshainer": 1,
#           "Berge": 1,
#           "Landeskrone": 1,
#           "Pferde": 1,
#           "Thale": 1,
#           "Thalschenke": 1,
#           "Sandweg": 1,
#           "Gehöftes": 1,
#           "Pferden": 1,
#           "Nachtquartier": 1,
#           "Sommerluft": 1,
#           "Grunde": 1,
#           "Damm": 1,
#           "Wege": 1,
#           "Sumpf": 1,
#           "Weg": 1,
#           "Wasser": 1,
#           "Walde": 1,
#           "Wald": 1,
#           "Stadtwald": 1,
#           "Rasenfläche": 1,
#           "Weiher": 1,
#           "Kieswege": 1,
#           "Thalgrund": 1,
#           "Gebüsch": 1,
#           "Gartenbank": 1,
#           "Flur": 1,
#           "Waldwiese": 1,
#           "Wasserfläche": 1,
#           "Nebelmassen": 1,
#           "Luftgebilde": 1,
#           "Luft": 1,
#           "Flor": 1,
#           "Wiese": 1,
#           "Thal": 1,
#           "Hause": 1
#         },
#         "Dimensioning-Distance": {
#           "Mark": 3,
#           ",": 2,
#           "Zwei": 1,
#           "drei": 1,
#           "vier": 1,
#           "fünfzig": 1,
#           "vom": 1,
#           "Bahnhof": 1,
#           "entfernt": 1,
#           "von": 1,
#           "zweihundert": 1,
#           "Kilometern": 1,
#           "meilenweit": 1,
#           "tiefe": 1,
#           "Weiterhin": 1,
#           "fußtiefen": 1,
#           "tief": 1,
#           "tiefen": 1,
#           "hochgelegene": 1,
#           "fernen": 1,
#           "unfern": 1,
#           "fern": 1,
#           "soweit": 1,
#           "das": 1,
#           "Auge": 1,
#           "reicht": 1,
#           "nächsten": 1,
#           "nahe": 1
#         },
#         "Movement-Light": {
#           "auf": 2,
#           "sah": 2,
#           "ausschaue": 1,
#           "entdecke": 1,
#           "lese": 1,
#           "traf": 1,
#           "nahm": 1,
#           "fotografierte": 1,
#           "auszublicken": 1,
#           "übersehen": 1,
#           "ansah": 1,
#           "blinken": 1,
#           "fallen": 1,
#           "erleuchtet": 1,
#           "erglühte": 1,
#           "blitzendem": 1,
#           "überströmte": 1,
#           "erquicken": 1,
#           "angaffte": 1,
#           "stechen": 1,
#           "heraufwinkte": 1,
#           "um": 1,
#           "fällt": 1,
#           "besprengt": 1,
#           "schimmernden": 1,
#           "zündet": 1,
#           "läuft": 1,
#           "herab": 1,
#           "brennender": 1,
#           "leuchten": 1,
#           "erleuchten": 1,
#           "wirf": 1,
#           "hinaus": 1,
#           "umherflackert": 1,
#           "sieht": 1,
#           "hinüber": 1,
#           "mattscheinend": 1,
#           "leuchtenden": 1,
#           "schimmern": 1,
#           "erleuchtete": 1,
#           "glänzt": 1,
#           "hineinzuwerfen": 1,
#           "blickt": 1
#         },
#         "Positioning": {
#           "in": 18,
#           "im": 13,
#           "an": 11,
#           "der": 8,
#           "auf": 6,
#           "unter": 6,
#           "dort": 6,
#           "des": 4,
#           "da": 4,
#           "Hier": 4,
#           "hier": 4,
#           "In": 3,
#           "am": 3,
#           "irgendwo": 2,
#           "darin": 2,
#           "mit": 2,
#           "über": 2,
#           "Da": 2,
#           "darunter": 2,
#           "von": 2,
#           "Hand": 2,
#           "draußen": 1,
#           "umstehenden": 1,
#           "Inmitten": 1,
#           "Am": 1,
#           "Hie": 1,
#           "hie": 1,
#           "Vorn": 1,
#           "Im": 1,
#           "dieses": 1,
#           "Links": 1,
#           "Hinter": 1,
#           "einer": 1,
#           "mehrerer": 1,
#           "hinter": 1,
#           "jenseits": 1,
#           "linker": 1,
#           "Dazwischen": 1,
#           "zwischen": 1,
#           "Auf": 1,
#           "ihrem": 1,
#           "Vor": 1,
#           "seiner": 1,
#           "oben": 1,
#           "vor": 1,
#           "zur": 1,
#           "linken": 1,
#           "obern": 1
#         },
#         "Movement-Object": {
#           "verirrte": 1,
#           "taumelte": 1,
#           "hievte": 1,
#           "bewässern": 1,
#           "einsanken": 1,
#           "streiften": 1,
#           "rauchenden": 1,
#           "flog": 1,
#           "hinab": 1,
#           "blieb": 1,
#           "stecken": 1,
#           "gezogen": 1,
#           "herumwälzt": 1,
#           "breitet": 1,
#           "ballt": 1,
#           "flattern": 1,
#           "ziehen": 1,
#           "verwebend": 1,
#           "erheben": 1,
#           "schweben": 1,
#           "sammelt": 1,
#           "schweifen": 1,
#           "umhüllt": 1,
#           "dringt": 1,
#           "heran": 1,
#           "zusammenbricht": 1,
#           "gleitet": 1,
#           "vorüber": 1,
#           "Weicht": 1,
#           "rollende": 1,
#           "träufeln": 1
#         },
#         "Place-Object": {
#           "Mond": 4,
#           "Himmel": 2,
#           "Sperre": 1,
#           "Rinnstein": 1,
#           "Türschlösser": 1,
#           "Sandboden": 1,
#           "Boden": 1,
#           "Erdreich": 1,
#           "Sande": 1,
#           "Dach": 1,
#           "Sonne": 1,
#           "Wolkenschichten": 1,
#           "Sternen": 1,
#           "Erde": 1,
#           "Fensterreihe": 1,
#           "Scheiben": 1
#         },
#         "Dimensioning-Size": {
#           "dürre": 2,
#           "langen": 2,
#           "großer": 2,
#           "mittelgroßen": 1,
#           "dreibahnig": 1,
#           "ausgebauten": 1,
#           "massigen": 1,
#           "dünnen": 1,
#           "bequemen": 1,
#           "ansehnlicher": 1,
#           "unermeßlichen": 1,
#           "großen": 1,
#           "ungeheuren": 1,
#           "niedriger": 1,
#           "untersetzter": 1,
#           "schmalen": 1,
#           "breiten": 1,
#           "breite": 1,
#           "hohe": 1,
#           "weite": 1,
#           "endlosen": 1,
#           "höher": 1,
#           "gebeugte": 1,
#           "knieenden": 1,
#           "große": 1,
#           "stattliche": 1,
#           "von": 1,
#           "guter": 1,
#           "Mittelgröße": 1
#         },
#         "Place-ALT": {
#           "Ecke": 1,
#           "Kirche": 1,
#           "Mitte": 1,
#           "Anfang": 1,
#           "Stück": 1,
#           "Geschäft": 1,
#           "Oede": 1,
#           "Sonne": 1
#         },
#         "Movement-Sound": {
#           "gefragt": 1,
#           "nennt": 1,
#           "geknallt": 1,
#           "singe": 1,
#           "lache": 1,
#           "erkundigt": 1,
#           "rauschende": 1,
#           "behandelte": 1,
#           "fragenden": 1,
#           "anredete": 1,
#           "sagte": 1,
#           "wispert": 1,
#           "tönt": 1
#         },
#         "Direction-ALT": {
#           "in": 3,
#           "zu": 3,
#           "auf": 2,
#           "über": 2,
#           "aus": 1,
#           "ans": 1,
#           "bis": 1,
#           "ins": 1,
#           "nach": 1,
#           "von": 1,
#           "zur": 1,
#           "Zu": 1
#         },
#         "Positioning-ALT": {
#           "in": 2,
#           "im": 1,
#           "hinter": 1,
#           "jener": 1
#         },
#         "Place-Object-MC": {
#           "Fenster": 3,
#           "Boden": 1,
#           "Seite": 1,
#           "Horizont": 1,
#           "Hausthür": 1,
#           "Mond": 1
#         },
#         "Place-Abstract": {
#           "Fuße": 2,
#           "Grenzen": 1,
#           "Bogen": 1,
#           "Gipfel": 1,
#           "Spitze": 1
#         },
#         "Place-Abstract-MC": {
#           "Ecke": 1
#         },
#         "Movement-Smell": {
#           "wohlriechend": 1
#         }
#       }
#     }
#   }
# }

# %%
# safe annotation statistics to files

for result_type in results:
    filename: str = f'annotation_statistics__{result_type}.json'
    json_file_str: str = json.dumps(results[result_type], indent=2, sort_keys=False, ensure_ascii=False)

    if (os.path.isfile(filename)):
        print(f'JSON file {filename} already exists and will be overwritten.')

    with open(filename, 'w') as file:
        file.write(json_file_str)
        print(f'JSON file {filename} successfully created.')
# Out:
# JSON file annotation_statistics__whole_chapters.json already exists and will be overwritten.
# JSON file annotation_statistics__whole_chapters.json successfully created.
# JSON file annotation_statistics__first_1000_token.json already exists and will be overwritten.
# JSON file annotation_statistics__first_1000_token.json successfully created.

# %%
# create bar chart with annotation amounts of all first chapters normalized to their token amount: all tokens

data_dict: dict = {
    'text': list(itertools.chain(*[[item] * 21 for item in [
        'DEU19_030', 
        'DEU19_001', 
        'DEU20_002', 
        'DEU20_021', 
        'SPA19_001', 
        'SPA19_008', 
        'LAT19_004', 
        'LAT19_041'
    ]])),
    'annotation_class': [
        'Place-Container', 
        'Place-Container-MC', 
        'Place-Object', 
        'Place-Object-MC', 
        'Place-Abstract', 
        'Place-Abstract-MC', 
        'Place-ALT',
        'Movement-Subject',
        'Movement-Object',
        'Movement-Light',
        'Movement-Sound',
        'Movement-Smell',
        'Movement-ALT',
        'Dimensioning-Size',
        'Dimensioning-Distance',
        'Dimensioning-Amount',
        'Dimensioning-ALT',
        'Positioning',
        'Positioning-ALT',
        'Direction',
        'Direction-ALT'
    ] * 8,
    'amount': []
}
data_dict['amount'] = list(itertools.chain(*[[results['whole_chapters']['ratios']['cs1'][corpus_file[0]][corpus_file[1]]['annotations_by_class_in_file:total_token_amount_in_file'].get(annotation_class, 0) * 100] for corpus_file in [
    ('canspin-deu-19', 'CANSpiN-deu-19_030_1-1-1.tsv'), 
    ('canspin-deu-19', 'CANSpiN-deu-19_001_1-1-1.tsv'),
    ('canspin-deu-20', 'CANSpiN-deu-20_002_1.tsv'),
    ('canspin-deu-20', 'CANSpiN-deu-20_021_1.tsv'),
    ('canspin-spa-19', 'CANSpiN-spa-19_001_1.tsv'),
    ('canspin-spa-19', 'CANSpiN-spa-19_008_1.tsv'),
    ('canspin-lat-19', 'CANSpiN-lat-19_004_1.tsv'),
    ('canspin-lat-19', 'CANSpiN-lat-19_041_1.tsv')
] for annotation_class in data_dict['annotation_class'][:21]]))

data: pd.DataFrame = pd.DataFrame(data_dict)

figure: plotly.graph_objects.Figure = plotly.express.bar(
    data_frame=data,
    x='text',
    y='amount',
    color='annotation_class',
    labels={
        "text": "texts",
        "amount": "annotation amount (in %)",
        "annotation_class": "annotation classes"
    },
    title='CS1 annotation amounts inside the initial chapters with all tokens <br><sub>(in percentage of the total token amount of the respective chapter)</sub>',
    color_discrete_map={
        'Place-Container': '#B6D3FF',
        'Place-Container-MC': '#CCDEFF',
        'Place-Object': '#D4EAFF',
        'Place-Object-MC': '#E6F2FF',
        'Place-Abstract': '#89A8F6',
        'Place-Abstract-MC': '#98C3FA',
        'Place-ALT': '#90A6C7',
        'Movement-Subject': '#FF6D6D',
        'Movement-Object': '#F60D00',
        'Movement-Sound': '#FF4949',
        'Movement-Light': '#CA0B0B',
        'Movement-Smell': '#B60000',
        'Movement-ALT': '#960000',
        'Direction': '#92FFBD',
        'Direction-ALT': '#75CC96',
        'Positioning': '#DB8300',
        'Positioning-ALT': '#B56A01',
        'Dimensioning-Distance': '#8AB6AD',
        'Dimensioning-Size': '#7CD3C0',
        'Dimensioning-Amount': '#7EF5D9',
        'Dimensioning-ALT': '#60847B'
    },
    width=1400,
    height=800
)

figure.update_layout(font={'size': 18})

figure.show()

# %%
# create bar chart with annotation amounts of all first chapters normalized to their token amount: selected tokens

data_dict: dict = {
    'text': list(itertools.chain(*[[item] * 21 for item in [
        'DEU19_030', 
        'DEU19_001', 
        'DEU20_002', 
        'DEU20_021', 
        'SPA19_001', 
        'SPA19_008', 
        'LAT19_004', 
        'LAT19_041'
    ]])),
    'annotation_class': [
        'Place-Container', 
        'Place-Container-MC', 
        'Place-Object', 
        'Place-Object-MC', 
        'Place-Abstract', 
        'Place-Abstract-MC', 
        'Place-ALT',
        'Movement-Subject',
        'Movement-Object',
        'Movement-Light',
        'Movement-Sound',
        'Movement-Smell',
        'Movement-ALT',
        'Dimensioning-Size',
        'Dimensioning-Distance',
        'Dimensioning-Amount',
        'Dimensioning-ALT',
        'Positioning',
        'Positioning-ALT',
        'Direction',
        'Direction-ALT'
    ] * 8,
    'amount': []
}
data_dict['amount'] = list(itertools.chain(*[[results['first_1000_token']['ratios']['cs1'][corpus_file[0]][corpus_file[1]]['annotations_by_class_in_file:total_token_amount_in_file'].get(annotation_class, 0) * 100] for corpus_file in [
    ('canspin-deu-19', 'CANSpiN-deu-19_030_1-1-1.tsv'), 
    ('canspin-deu-19', 'CANSpiN-deu-19_001_1-1-1.tsv'),
    ('canspin-deu-20', 'CANSpiN-deu-20_002_1.tsv'),
    ('canspin-deu-20', 'CANSpiN-deu-20_021_1.tsv'),
    ('canspin-spa-19', 'CANSpiN-spa-19_001_1.tsv'),
    ('canspin-spa-19', 'CANSpiN-spa-19_008_1.tsv'),
    ('canspin-lat-19', 'CANSpiN-lat-19_004_1.tsv'),
    ('canspin-lat-19', 'CANSpiN-lat-19_041_1.tsv')
] for annotation_class in data_dict['annotation_class'][:21]]))

data: pd.DataFrame = pd.DataFrame(data_dict)

figure: plotly.graph_objects.Figure = plotly.express.bar(
    data_frame=data,
    x='text',
    y='amount',
    color='annotation_class',
    labels={
        "text": "texts",
        "amount": "annotation amount (in %)",
        "annotation_class": "annotation classes"
    },
    title=f'CS1 annotation amounts inside the initial chapters with {token_selection[1] - token_selection[0]} tokens <br><sub>(in percentage of the selected token amount of the respective chapter)</sub>',
    color_discrete_map={
        'Place-Container': '#B6D3FF',
        'Place-Container-MC': '#CCDEFF',
        'Place-Object': '#D4EAFF',
        'Place-Object-MC': '#E6F2FF',
        'Place-Abstract': '#89A8F6',
        'Place-Abstract-MC': '#98C3FA',
        'Place-ALT': '#90A6C7',
        'Movement-Subject': '#FF6D6D',
        'Movement-Object': '#F60D00',
        'Movement-Sound': '#FF4949',
        'Movement-Light': '#CA0B0B',
        'Movement-Smell': '#B60000',
        'Movement-ALT': '#960000',
        'Direction': '#92FFBD',
        'Direction-ALT': '#75CC96',
        'Positioning': '#DB8300',
        'Positioning-ALT': '#B56A01',
        'Dimensioning-Distance': '#8AB6AD',
        'Dimensioning-Size': '#7CD3C0',
        'Dimensioning-Amount': '#7EF5D9',
        'Dimensioning-ALT': '#60847B'
    },
    width=1400,
    height=800
)

figure.show()
